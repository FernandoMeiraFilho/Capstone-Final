# %% [markdown]
# # Final Code

# %% [markdown]
# <div class="alert alert-success">
# All of the concepts on choosing the subsets and data particularities in this code is concluded from the 'EDA - analysing Nans' notebook, which is also included in this repository. <br> <br>
#
# </div>

# %% [markdown]
# # Dataset tuning

# %% [markdown]
# All of this steps below are based on the EDA notebook also present in this repository.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Math, Latex
from scipy import stats, linalg
% matplotlib inline


df = pd.read_csv('SPcities2.csv', decimal=',', encoding='Iso-8859-1', sep=';')

## Seting the data as seeing in the EDA notebook ( also in this repository)
df = df[df.year > 2001]
df = df[df.year < 2016]

data = df[df.year == 2013] # like we saw in the EDA on missing values, 2013 should be the best year for our analysis
                           # this was the case because, for this method, we need the year with more information, 
                            # in this case 2013

# cleaning the all null features

data_clean = data
data_clean = data_clean.drop('HDI', 1)
data_clean = data_clean.drop('educ_superior', 1)
data_clean = data_clean.drop('tax_revenue', 1)

# %% [markdown]
# ------------------------------------------------ END OF DATASET TUNING ----------------------------------------------

# %% [markdown]
# The I-Distance method:

# %% [markdown]
# <img src='Idistancenorm.png'> </img>

# %% [markdown]
# The I-Distance <b>squared</b> method:

# %% [markdown]
# <img src='idistance.png'> </img>

# %% [markdown]
# <img src='disceffect.png'> </img>

# %% [markdown]
# "where di(r, s) is the distance between the values of variable Xi for er and es e.g. the discriminate effect" and <br> <br>
#
# "σi the standard deviation of Xi, and rji.12 … j − 1 is a partial coefficient of the correlation between Xi and Xj, (j < i)"

# %% [markdown]
# # Creating the tools to use the method

# %%
# this idea for partial correlation was obtained from : https://gist.github.com/fabianp/9396204419c7b638d38f

## Partial Correlation Matrix for the rij variable in the formula

from scipy import stats, linalg

def partial_corr(C):
    """
    Returns the sample linear partial correlation coefficients between pairs of variables in C, controlling 
    for the remaining variables in C.
    Parameters
    ----------
    C : array-like, shape (n, p)
        Array with the different variables. Each column of C is taken as a variable
    Returns
    -------
    P : array-like, shape (p, p)
        P[i, j] contains the partial correlation of C[:, i] and C[:, j] controlling
        for the remaining variables in C.
    """
    
    C = np.asarray(C)
    p = C.shape[1]
    P_corr = np.zeros((p, p), dtype=np.float)
    for i in range(p):
        P_corr[i, i] = 1
        for j in range(i+1, p):
            idx = np.ones(p, dtype=np.bool)
            idx[i] = False
            idx[j] = False
            beta_i = linalg.lstsq(C[:, idx], C[:, j])[0]
            beta_j = linalg.lstsq(C[:, idx], C[:, i])[0]

            res_j = C[:, j] - C[:, idx].dot( beta_i)
            res_i = C[:, i] - C[:, idx].dot(beta_j)
            
            corr = stats.pearsonr(res_i, res_j)[0]
            P_corr[i, j] = corr
            P_corr[j, i] = corr

        
    return P_corr

# %%
# The reference hyperplane to calculate all the distances from.
# Here we are going to set the city with the smallest value for GDP per capita

data_clean.sort_values('gdp_per', ascending=True).head()
# Out:
#                       city  year  gdp_per  gdp_growth  private_inv  \
# 4450   Itapirapuã Paulista  2013  6956.90    0.098176          NaN
# 10196             Taquaral  2013  7307.11   -0.110965          NaN
# 8462              Riversul  2013  7386.98    0.132233          NaN
# 7816              Pracinha  2013  7650.01    0.210545          NaN
# 285     Álvaro de Carvalho  2013  7653.97   -0.031318          NaN
#
#           pub_inv  export  import  violence  primary_enrolls     ...       \
# 4450    917044.27     NaN     NaN        12           102.25     ...
# 10196    91200.00     NaN     NaN         9            89.24     ...
# 8462          NaN     NaN     NaN        72            94.24     ...
# 7816          NaN     NaN     NaN         7            99.51     ...
# 285    1162680.60     NaN     NaN        29           100.62     ...
#
#        hosp_rooms  hosp_rooms_per   jobs  jobs_revenue  population  urban_pop  \
# 4450          NaN             NaN  521.0       1266.38        3954       1959
# 10196         NaN             NaN  500.0       1159.92        2729       2623
# 8462          NaN             NaN  533.0       1188.74        6003       4423
# 7816          NaN             NaN  264.0       1307.56        2864       1372
# 285           NaN             NaN  359.0       1443.34        4763       3081
#
#        rural_pop  olding  urbing  fundamental
# 4450      1995.0   42.32   49.54         64.0
# 10196      106.0   74.68   96.12         34.0
# 8462      1580.0   76.79   73.68         64.0
# 7816      1492.0   77.06   47.91         17.0
# 285       1682.0   60.52   64.69         55.0
#
# [5 rows x 26 columns]

# %% [markdown]
# Here, since the city of Itapirapua Paulista has the smallest value for the features of our most interest, it will be the hyperplane reference for our calculations.

# %%
data_values = data_clean.drop('year' ,1).fillna(0) # Base dataset for all calculations


reference = data_values.sort_values('gdp_per', ascending=True).iloc[0:1,:] # Base reference for all calculations

# %% [markdown]
# # Building the function to calculate the I-distance squared

# %% [markdown]
# Like the steps followed by <a href="http://www.sciencedirect.com/science/article/pii/S0264999314000558">reference article </a> , we should : <br>
#
# <ol>
# <li>Calculate the value of the discriminate effect of the variable X1, the most significant variable, that which provides the largest amount of information on the phenomena that is to be ranked; </li>
# <li> Add the value of the discriminate effect of X2 which is not covered by X1;</li>
# <li> Add the value of the discriminate effect of X3 which is not covered by X1 and X2;</li>
# <li> Repeat the procedure for all variables;</li>
# <li> Calculte the correlation coefficient of each indicator with the I-distance;</li>
# <li> Exclude the smallest non significant coefficient;</li>
# <li> Repeat (6) until only significant features remain.</li>

# %%
## Creating a function to the calculation to operate 1-4 above: 

def I_distance(data_values, reference):
    
    # getting the correlation matrix done
    data_corr = data_values.drop('city' ,1).fillna(0)
    col_labels = list(data_corr.columns)
    corre = pd.DataFrame(partial_corr(data_corr), columns=col_labels)
                         
    #starting the I-Distance calculation                     
    ncolums = data_corr.shape[1]
    nrows = data_corr.shape[0]
    somatory = []
    i2_index = {'city': [], 'I-Distance': []}
    for r in range(0,nrows):
        somatory = []    
        for i in range(0,ncolums):
            prod = 1
            summ_1 = 0
            summ_1 = ((data_corr.iloc[r,i] - reference.iloc[0,i+1])**2)/np.var(data_corr.iloc[:,i]) #distance squared divided by variance
            for k in range(i+1):
                if corre.iloc[i,k] == 1:
                    prod *= 1
                else:
                    prod *= (1-(corre.iloc[i,k])**2)
            somatory.append(summ_1*prod)
        i2_index['city'].append(data_values.iloc[r,0])
        i2_index['I-Distance'].append(np.cumsum(somatory)[-1])
    

## 5 - 6 selecting sigficant features

# calculating the rank of features and p-values

    distance = pd.DataFrame(i2_index)

    data = data_values.iloc[:,1:]
    feature_rank = {'feature': [], 'r': [], 'p-value': []}

    # creating the rank with correlation, p-values and name of features
    for col, values in data.iteritems():
        feature_rank['feature'].append(col)
        feature_rank['r'].append(stats.pearsonr(values, distance['I-Distance'])[0])
        feature_rank['p-value'].append(stats.pearsonr(values, distance['I-Distance'])[1])
    

    # manipulating the rank to select smallest correlation value with no significant p-value valor (>0.01)
    rank = pd.DataFrame(feature_rank)
    lenght_rank = len(list(rank.columns))
  
    excluded = {'feature' : "" , 'p-value' : 0 }
    for x in range(lenght_rank):
        excluded = {'feature' : "" , 'p-value' : 0 }
        chk = 0
        if rank.sort_values('r').iloc[x,1] >= 0.05 and x <= lenght_rank:  # check if the smallest r value is significant
            excluded['feature'] = rank.sort_values('r').iloc[x,0]
            excluded['p-value'] = rank.sort_values('r').iloc[x,1]
            chk = 1
            break
        elif rank.sort_values('r').iloc[x,1] <= 0.05 and x == lenght_rank:
            chk = 0
            break
        else:
            chk = 0
            continue

    if chk == 1: # returning new data frame if there is some variable to exclude, otherwise is done
        n_values = data_values.drop(excluded['feature'], 1)
        n_ref = reference.drop(excluded['feature'], 1)
        return 'loop',distance,  n_values, n_ref, excluded
    else:
        return 'done', distance, rank, 'ref', excluded # if no features to drop, return distance and rank

# %%
# 7 - Iterating for the final model until we gett only significant features:

def Final_distance(data_values, reference):
    check, distance, rank, ref, excluded = I_distance(data_values, reference)
    
    cont=1
    while True:
        if check == 'loop':
            print("Iteration of Number: ", cont)
            print("Variable excluded in this iteration:", excluded )
            print("I-Distance rank:")
            print(distance)
            check, distance, rank, ref, excluded = I_distance(rank, ref)
            cont += 1
            continue
        else:
            print("Iterations needed: ", cont-1)
            break
    return check, distance, rank

# %% [markdown]
# <h3> The Results for the I-Distance Squared</h3>

# %%
check1, distance1, rank1 = Final_distance(data_values, reference)
# Out:
# Iteration of Number:  1
# Variable excluded in this iteration: {'feature': 'olding', 'p-value': 0.62152333001401172}
# I-Distance rank:
#      I-Distance                    city
# 0     19.574375              Adamantina
# 1     12.623635                  Adolfo
# 2      7.619452                   Aguaí
# 3     14.912675          Águas da Prata
# 4     10.553639        Águas de Lindóia
# 5      4.973449  Águas de Santa Bárbara
# 6    175.278901      Águas de São Pedro
# 7     14.560906                  Agudos
# 8      2.860073                Alambari
# 9     13.647056       Alfredo Marcondes
# 10     7.707353                  Altair
# 11     9.946214             Altinópolis
# 12    16.617030             Alto Alegre
# 13    55.358300                Alumínio
# 14    20.329446        Álvares Florence
# 15     6.563823         Álvares Machado
# 16     1.786611      Álvaro de Carvalho
# 17     5.934405             Alvinlândia
# 18    24.343443               Americana
# 19    12.963261     Américo Brasiliense
# 20     8.488222       Américo de Campos
# 21    17.353354                  Amparo
# 22     5.603509               Analândia
# 23    14.095144               Andradina
# 24     6.805986                Angatuba
# 25     4.664807                 Anhembi
# 26     7.810902                 Anhumas
# 27     9.137248               Aparecida
# 28    15.335710       Aparecida d'Oeste
# 29    15.155430                   Apiaí
# ..          ...                     ...
# 615    7.572549                Tremembé
# 616   11.985928         Três Fronteiras
# 617    6.288230                  Tuiuti
# 618   31.352973                    Tupã
# Iteration of Number:  3
# Variable excluded in this iteration: {'feature': 'gdp_growth', 'p-value': 0.75378316318785343}
# I-Distance rank:
#      I-Distance                    city
# 0     12.115960              Adamantina
# 1      8.042414                  Adolfo
# 2      5.056758                   Aguaí
# 3      7.970469          Águas da Prata
# 4      7.530465        Águas de Lindóia
# 5      3.121306  Águas de Santa Bárbara
# 6    153.385922      Águas de São Pedro
# 7     11.496496                  Agudos
# 8      2.146873                Alambari
# 9      4.127744       Alfredo Marcondes
# 10     6.104993                  Altair
# 11     4.710981             Altinópolis
# 12     7.030864             Alto Alegre
# 13    54.204979                Alumínio
# 14     3.683619        Álvares Florence
# 15     4.430957         Álvares Machado
# 16     1.286850      Álvaro de Carvalho
# 17     4.724730             Alvinlândia
# 18    21.516335               Americana
# 19    11.599996     Américo Brasiliense
# 20     3.041638       Américo de Campos
# 21    10.372747                  Amparo
# 22     4.092833               Analândia
# 23     7.878665               Andradina
# 24     3.677725                Angatuba
# 25     3.797024                 Anhembi
# 26     5.817042                 Anhumas
# 27     7.273129               Aparecida
# 28     7.178189       Aparecida d'Oeste
# 29     5.120838                   Apiaí
# ..          ...                     ...
# 615    6.492500                Tremembé
# 616    4.911640         Três Fronteiras
# 617    1.509872                  Tuiuti
# 618   22.872681                    Tupã
# 619    3.544113           Tupi Paulista
# 620    3.200305                 Turiúba
# 621    2.072378               Turmalina
# 622   11.407513                 Ubarana
# 623    6.564373                 Ubatuba
# 624    2.032332               Ubirajara
# 625    6.009438                   Uchoa
# 626    3.225777          União Paulista
# 627    7.625911                  Urânia
# 628    8.397352                     Uru
# 629    4.814990                  Urupês
# 630    4.658696         Valentim Gentil
# 631   19.139425                Valinhos
# 632   10.441102              Valparaíso
# 633    0.891691                  Vargem
# 634    6.320430    Vargem Grande do Sul
# 635   11.795515  Vargem Grande Paulista
# 636   22.504668         Várzea Paulista
# 637    6.202632               Vera Cruz
# 638   34.293691                 Vinhedo
# 639    5.693407               Viradouro
# 640   15.366013    Vista Alegre do Alto
# 641    3.397748          Vitória Brasil
# 642   10.853895              Votorantim
# 643    8.018165             Votuporanga
# 644    3.869522                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  4
# Variable excluded in this iteration: {'feature': 'hosp_rooms_per', 'p-value': 0.37582986912677707}
# I-Distance rank:
#      I-Distance                    city
# 0     12.074408              Adamantina
# 1      4.983056                  Adolfo
# 2      4.855316                   Aguaí
# 3      7.984253          Águas da Prata
# 4      6.493129        Águas de Lindóia
# 5      2.764992  Águas de Santa Bárbara
# 6    155.455462      Águas de São Pedro
# 7     10.964515                  Agudos
# 8      1.969329                Alambari
# 9      3.406097       Alfredo Marcondes
# 10     6.010449                  Altair
# 11     4.293898             Altinópolis
# 12     5.720671             Alto Alegre
# 13    53.406963                Alumínio
# 14     1.780894        Álvares Florence
# 15     4.300596         Álvares Machado
# 16     0.654141      Álvaro de Carvalho
# 17     4.639451             Alvinlândia
# 18    21.395524               Americana
# 19    11.105158     Américo Brasiliense
# 20     3.003254       Américo de Campos
# 21    10.358998                  Amparo
# 635   11.857846  Vargem Grande Paulista
# 636   22.677522         Várzea Paulista
# 637    6.084709               Vera Cruz
# 638   34.029307                 Vinhedo
# 639    5.060882               Viradouro
# 640   15.123104    Vista Alegre do Alto
# 641    3.396479          Vitória Brasil
# 642   10.398229              Votorantim
# 643    7.233832             Votuporanga
# 644    3.660493                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  6
# Variable excluded in this iteration: {'feature': 'private_inv', 'p-value': 0.091851832194846592}
# I-Distance rank:
#      I-Distance                    city
# 0      3.378890              Adamantina
# 1      2.783089                  Adolfo
# 2      2.760523                   Aguaí
# 3      2.593397          Águas da Prata
# 4      3.098946        Águas de Lindóia
# 5      1.852727  Águas de Santa Bárbara
# 6      5.142657      Águas de São Pedro
# 7      8.296152                  Agudos
# 8      0.882173                Alambari
# 9      1.882651       Alfredo Marcondes
# 10     2.934439                  Altair
# 11     2.196695             Altinópolis
# 12     1.404890             Alto Alegre
# 13    52.560349                Alumínio
# 14     1.298940        Álvares Florence
# 15     2.360734         Álvares Machado
# 16     0.381523      Álvaro de Carvalho
# 17     2.085454             Alvinlândia
# 18    17.774734               Americana
# 19     5.348386     Américo Brasiliense
# 20     1.530359       Américo de Campos
# 21     6.997246                  Amparo
# 22     2.412159               Analândia
# 23     5.004059               Andradina
# 24     2.074976                Angatuba
# 25     3.006902                 Anhembi
# 26     1.667357                 Anhumas
# 27     3.361114               Aparecida
# 28     1.308143       Aparecida d'Oeste
# 29     1.739496                   Apiaí
# ..          ...                     ...
# 615    3.099009                Tremembé
# 616    1.980412         Três Fronteiras
# 617    1.070352                  Tuiuti
# 618    3.535925                    Tupã
# 619    1.191009           Tupi Paulista
# 620    1.516702                 Turiúba
# 621    0.934997               Turmalina
# 622    8.149212                 Ubarana
# 623    3.067231                 Ubatuba
# 624    0.619749               Ubirajara
# 625    3.833588                   Uchoa
# 626    1.542329          União Paulista
# 627    1.732493                  Urânia
# 628    1.853868                     Uru
# 629    2.078025                  Urupês
# 630    2.549716         Valentim Gentil
# 631   14.090264                Valinhos
# 632    6.657252              Valparaíso
# 633    0.216594                  Vargem
# 634    2.832971    Vargem Grande do Sul
# 635    9.198171  Vargem Grande Paulista
# 636   15.443734         Várzea Paulista
# 637    1.738494               Vera Cruz
# 638   30.161082                 Vinhedo
# 639    2.386001               Viradouro
# 640   11.785706    Vista Alegre do Alto
# 641    1.993155          Vitória Brasil
# 642    7.320236              Votorantim
# 643    4.476984             Votuporanga
# 644    2.573962                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  7
# Variable excluded in this iteration: {'feature': 'urbing', 'p-value': 0.10763222822410638}
# I-Distance rank:
#      I-Distance                    city
# 0      3.381772              Adamantina
# 1      2.784285                  Adolfo
# 2      2.762508                   Aguaí
# 3      2.595211          Águas da Prata
# 4      3.102472        Águas de Lindóia
# 5      1.853445  Águas de Santa Bárbara
# 6      5.147547      Águas de São Pedro
# 7      8.298872                  Agudos
# 8      0.883089                Alambari
# 9      1.884172       Alfredo Marcondes
# 10     2.935367                  Altair
# 11     2.198509             Altinópolis
# 12     1.406023             Alto Alegre
# 13    52.621951                Alumínio
# 14     1.299403        Álvares Florence
# 15     2.362668         Álvares Machado
# 16     0.381768      Álvaro de Carvalho
# 17     2.087392             Alvinlândia
# 18    14.535485               Americana
# 19     5.351816     Américo Brasiliense
# 20     1.531821       Américo de Campos
# 21     6.999554                  Amparo
# 22     2.413227               Analândia
# 23     5.007130               Andradina
# 24     2.075610                Angatuba
# 25     3.007379                 Anhembi
# 26     1.668710                 Anhumas
# 27     3.349952               Aparecida
# 28     1.309522       Aparecida d'Oeste
# 29     1.740442                   Apiaí
# ..          ...                     ...
# 615    3.101248                Tremembé
# 616    1.981880         Três Fronteiras
# 617    1.070202                  Tuiuti
# 618    3.541709                    Tupã
# 619    1.192006           Tupi Paulista
# 620    1.517960                 Turiúba
# 621    0.935595               Turmalina
# 622    8.139457                 Ubarana
# 623    3.071419                 Ubatuba
# 624    0.620405               Ubirajara
# 625    3.835636                   Uchoa
# 626    1.543258          União Paulista
# 627    1.733962                  Urânia
# 628    1.854500                     Uru
# 629    2.079975                  Urupês
# 630    2.551868         Valentim Gentil
# 631   14.049568                Valinhos
# 632    6.659234              Valparaíso
# 633    0.216610                  Vargem
# 634    2.835712    Vargem Grande do Sul
# 635    9.209976  Vargem Grande Paulista
# 636   15.527562         Várzea Paulista
# 637    1.740205               Vera Cruz
# 638   30.100553                 Vinhedo
# 639    2.388736               Viradouro
# 640   11.786491    Vista Alegre do Alto
# 641    1.994509          Vitória Brasil
# 642    7.327091              Votorantim
# 643    4.143896             Votuporanga
# 644    2.574992                Zacarias
#
# [645 rows x 2 columns]
# Iterations needed:  7

# %%
rank1.sort_values('r', ascending=False)
# Out:
#          feature        p-value         r
# 4       violence   0.000000e+00  0.990580
# 11          jobs   0.000000e+00  0.989353
# 8   services_add   0.000000e+00  0.985795
# 6      value_add   0.000000e+00  0.982313
# 14     urban_pop   0.000000e+00  0.978691
# 13    population   0.000000e+00  0.978607
# 10    hosp_rooms   0.000000e+00  0.976214
# 16   fundamental   0.000000e+00  0.972127
# 1        pub_inv   0.000000e+00  0.951517
# 9     eletricity  8.198462e-314  0.944806
# 7   industry_add  4.002641e-288  0.933264
# 15     rural_pop  4.962174e-113  0.740399
# 3         import   1.767463e-86  0.673588
# 2         export   3.427779e-85  0.669827
# 5    density_pop   8.103492e-13  0.276907
# 12  jobs_revenue   3.553167e-05  0.162043
# 0        gdp_per   1.193716e-02  0.098937

# %%
distance1.sort_values('I-Distance', ascending=False)
# Out:
#       I-Distance                     city
# 564  5420.100823                São Paulo
# 568   253.370130            São Sebastião
# 559   150.584562      São José dos Campos
# 234   142.742285            Ilha Comprida
# 546   120.551111    São Bernardo do Campo
# 153   114.357130                  Diadema
# 544   112.603475                   Santos
# 310   112.293461                 Louveira
# 590   104.851029          Taboão da Serra
# 64    102.321066                  Barueri
# 389   100.644117                   Osasco
# 547    91.586236       São Caetano do Sul
# 214    87.955723                Guarulhos
# 107    85.668883                 Campinas
# 120    78.343459              Carapicuíba
# 412    58.143407                 Paulínia
# 13     43.994971                 Alumínio
# 295    41.225816                  Jundiaí
# 583    40.666734                 Sorocaba
# 332    39.531636                     Mauá
# 536    36.173007              Santo André
# 282    35.980659               Jaguariúna
# 435    34.704392               Piracicaba
# 102    33.638510                  Cajamar
# 150    32.175117                  Cubatão
# 285    30.865753                  Jandira
# 219    28.588303              Hortolândia
# 446    28.108262                      Poá
# 606    26.810150                  Taubaté
# 194    26.311014           Gavião Peixoto
# ..           ...                      ...
# 579     0.067592              Sete Barras
# 45      0.066880                  Aspásia
# 541     0.065759  Santo Antônio do Pinhal
# 164     0.062690                 Eldorado
# 273     0.060931                    Itobi
# 573     0.058822                 Sarutaiá
# 97      0.057360                  Caconde
# 329     0.055157              Marinópolis
# 60      0.051959          Barra do Chapéu
# 624     0.051210                Ubirajara
# 507     0.047334                Salmourão
# 141     0.045457           Coronel Macedo
# 272     0.039716                 Itirapuã
# 416     0.038255               Pedra Bela
# 238     0.037507                  Indiana
# 599     0.034734                 Taquaral
# 216     0.034345               Guzolândia
# 151     0.034056                    Cunha
# 263     0.033671               Itaporanga
# 556     0.033009     São José do Barreiro
# 245     0.027927                 Iporanga
# 40      0.022373                   Areias
# 542     0.020819           Santo Expedito
# 497     0.018268                 Riversul
# 299     0.018120                 Lagoinha
# 481     0.010638                  Ribeira
# 581     0.009802                Silveiras
# 459     0.007003                 Pracinha
# 293     0.005865           Júlio Mesquita
# 261     0.000000      Itapirapuã Paulista
#
# [645 rows x 2 columns]

# %% [markdown]
# Looking to visual correlations between the I-Distance index and public investment values

# %%
data_set = data_values[['city', 'pub_inv']].reindex(list(range(645))) #getting public investment 
scatter = distance1
scatterf = pd.merge(scatter, data_set, on='city') # creating the dataset with the paramter for the scatter plot


sns.lmplot('pub_inv', 'I-Distance', scatterf, size=7)

# %% [markdown]
# In spite of the fact that a good part of the cities don't have values for the feature, there is no evidence that, public investment alone contributes to better values for the index.

# %% [markdown]
# <h2>Making the I-Distance- not squared</h2>

# %%
def I_distance_norm(data_values, reference):
    
    # getting the correlation matrix done
    data_corr = data_values.drop('city' ,1).fillna(0)
    col_labels = list(data_corr.columns)
    corre = pd.DataFrame(partial_corr(data_corr), columns=col_labels)
                         
    #starting the I-Distance calculation                     
    ncolums = data_corr.shape[1]
    nrows = data_corr.shape[0]
    somatory = []
    i2_index = {'city': [], 'I-Distance': []}
    for r in range(0,nrows):
        somatory = []    
        for i in range(0,ncolums):
            prod = 1
            summ_1 = 0
            summ_1 = (np.absolute(data_corr.iloc[r,i] - reference.iloc[0,i+1]))/np.var(data_corr.iloc[:,i]) #distance squared divided by variance
            for k in range(i+1):
                if corre.iloc[i,k] == 1:
                    prod *= 1
                else:
                    prod *= (1-(corre.iloc[i,k]))
            somatory.append(summ_1*prod)
        i2_index['city'].append(data_values.iloc[r,0])
        i2_index['I-Distance'].append(np.cumsum(somatory)[-1])
    

## 5 - 6 selecting sigficant features

# calculating the rank of features and p-values

    distance = pd.DataFrame(i2_index)

    data = data_values.iloc[:,1:]
    feature_rank = {'feature': [], 'r': [], 'p-value': []}

    # creating the rank with correlation, p-values and name of features
    for col, values in data.iteritems():
        feature_rank['feature'].append(col)
        feature_rank['r'].append(stats.pearsonr(values, distance['I-Distance'])[0])
        feature_rank['p-value'].append(stats.pearsonr(values, distance['I-Distance'])[1])
    

    # manipulating the rank to select smallest correlation value with no significant p-value valor (>0.01)
    rank = pd.DataFrame(feature_rank)
    lenght_rank = len(list(rank.columns))
  
    excluded = {'feature' : "" , 'p-value' : 0 }
    for x in range(lenght_rank):
        excluded = {'feature' : "" , 'p-value' : 0 }
        chk = 0
        if rank.sort_values('r').iloc[x,1] >= 0.05 and x <= lenght_rank:  # check if the smallest r value is significant
            excluded['feature'] = rank.sort_values('r').iloc[x,0]
            excluded['p-value'] = rank.sort_values('r').iloc[x,1]
            chk = 1
            break
        elif rank.sort_values('r').iloc[x,1] <= 0.05 and x == lenght_rank:
            chk = 0
            break
        else:
            chk = 0
            continue

    if chk == 1: # returning new data frame if there is some variable to exclude, otherwise is done
        n_values = data_values.drop(excluded['feature'], 1)
        n_ref = reference.drop(excluded['feature'], 1)
        return 'loop',distance,  n_values, n_ref, excluded
    else:
        return 'done', distance, rank, 'ref', excluded # if no features to drop, return distance and rank

# %%
def Final_distance_norm(data_values, reference):
    check, distance, rank, ref, excluded = I_distance_norm(data_values, reference)
    
    cont=1
    while True:
        if check == 'loop':
            print("Iteration of Number: ", cont)
            print("Variable excluded in this iteration:", excluded )
            print("I-Distance rank:")
            print(distance)
            check, distance, rank, ref, excluded = I_distance_norm(rank, ref)
            cont += 1
            continue
        else:
            print("Iterations needed: ", cont-1)
            break
    return check, distance, rank

# %% [markdown]
# <h3> The Results for the I-Distance</h3>

# %%
check2, distance2, rank2 = Final_distance_norm(data_values, reference)
# Out:
# Iteration of Number:  1
# Variable excluded in this iteration: {'feature': 'olding', 'p-value': 0.083299559371892526}
# I-Distance rank:
#      I-Distance                    city
# 0      0.814315              Adamantina
# 1      8.844093                  Adolfo
# 2      2.093593                   Aguaí
# 3      0.365900          Águas da Prata
# 4      5.227990        Águas de Lindóia
# 5      3.029922  Águas de Santa Bárbara
# 6      3.832458      Águas de São Pedro
# 7      3.681509                  Agudos
# 8      2.065421                Alambari
# 9      4.285084       Alfredo Marcondes
# 10     1.814622                  Altair
# 11     3.294260             Altinópolis
# 12     6.294743             Alto Alegre
# 13     5.500123                Alumínio
# 14     7.037874        Álvares Florence
# 15     1.606620         Álvares Machado
# 16     4.014925      Álvaro de Carvalho
# 17     1.212043             Alvinlândia
# 18     2.036627               Americana
# 19     3.910296     Américo Brasiliense
# 20     0.307014       Américo de Campos
# 21     0.898899                  Amparo
# 22     0.806364               Analândia
# 23     0.511635               Andradina
# 24     1.113967                Angatuba
# 25     1.972824                 Anhembi
# 26     6.961708                 Anhumas
# 27     1.622757               Aparecida
# 28     1.942172       Aparecida d'Oeste
# 29     7.565611                   Apiaí
# ..          ...                     ...
# 615    1.748996                Tremembé
# 616    3.900394         Três Fronteiras
# 617    1.000258                  Tuiuti
# 618    1.266850                    Tupã
# Variable excluded in this iteration: {'feature': 'private_inv', 'p-value': 0.18014403573881851}
# I-Distance rank:
#      I-Distance                    city
# 0      0.732581              Adamantina
# 1      8.656857                  Adolfo
# 2      2.041451                   Aguaí
# 3      0.295483          Águas da Prata
# 4      5.106427        Águas de Lindóia
# 5      2.949732  Águas de Santa Bárbara
# 6      3.735354      Águas de São Pedro
# 7      3.604035                  Agudos
# 8      2.020179                Alambari
# 9      4.131634       Alfredo Marcondes
# 10     1.780453                  Altair
# 11     3.200023             Altinópolis
# 12     6.122950             Alto Alegre
# 13     5.421472                Alumínio
# 14     6.818867        Álvares Florence
# 15     1.544998         Álvares Machado
# 16     3.936697      Álvaro de Carvalho
# 17     1.172630             Alvinlândia
# 18     1.967422               Americana
# 19     3.848499     Américo Brasiliense
# 20     0.234174       Américo de Campos
# 21     0.841633                  Amparo
# 22     0.765273               Analândia
# 23     0.453464               Andradina
# 24     1.083479                Angatuba
# 25     1.927272                 Anhembi
# 26     6.829604                 Anhumas
# 27     1.571355               Aparecida
# 28     1.838373       Aparecida d'Oeste
# 29     7.446081                   Apiaí
# ..          ...                     ...
# 615    1.709430                Tremembé
# 616    3.770971         Três Fronteiras
# 617    0.931075                  Tuiuti
# 618    1.191048                    Tupã
# 619    1.426239           Tupi Paulista
# 620    2.952685                 Turiúba
# 621    2.431700               Turmalina
# 622    3.411841                 Ubarana
# 623    3.870794                 Ubatuba
# 624    2.104288               Ubirajara
# 625    1.326284                   Uchoa
# 626    0.930284          União Paulista
# 627    0.474913                  Urânia
# 628    1.089264                     Uru
# 629    2.469371                  Urupês
# 630    0.842754         Valentim Gentil
# 631    1.094670                Valinhos
# 632    2.216622              Valparaíso
# 633    3.759517                  Vargem
# 634    2.232683    Vargem Grande do Sul
# 635    0.605571  Vargem Grande Paulista
# 636    0.575952         Várzea Paulista
# 637    2.332790               Vera Cruz
# 638    2.458319                 Vinhedo
# 639    0.634966               Viradouro
# 640    2.505718    Vista Alegre do Alto
# 641    0.852117          Vitória Brasil
# 642    3.264664              Votorantim
# 643    2.181465             Votuporanga
# 644    2.399635                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  4
# Variable excluded in this iteration: {'feature': 'hosp_rooms_per', 'p-value': 0.21283738528240376}
# I-Distance rank:
#      I-Distance                    city
# 0      0.688238              Adamantina
# 1      8.656873                  Adolfo
# 2      2.041217                   Aguaí
# 3      0.296759          Águas da Prata
# 4      5.093685        Águas de Lindóia
# 5      2.949801  Águas de Santa Bárbara
# 6      3.741106      Águas de São Pedro
# 7      3.593813                  Agudos
# 8      2.020214                Alambari
# 9      4.131338       Alfredo Marcondes
# 10     1.781529                  Altair
# 11     3.189114             Altinópolis
# 12     6.095594             Alto Alegre
# 13     5.422662                Alumínio
# 14     6.819095        Álvares Florence
# 15     1.539991         Álvares Machado
# 16     3.936832      Álvaro de Carvalho
# 17     1.172721             Alvinlândia
# 18     1.930135               Americana
# 19     3.819180     Américo Brasiliense
# 20     0.233650       Américo de Campos
# 21     0.814191                  Amparo
# 22     0.765496               Analândia
# 23     0.440366               Andradina
# 636    0.562025         Várzea Paulista
# 637    2.338247               Vera Cruz
# 638    2.355814                 Vinhedo
# 639    0.433489               Viradouro
# 640    2.418225    Vista Alegre do Alto
# 641    0.855540          Vitória Brasil
# 642    3.173995              Votorantim
# 643    1.972328             Votuporanga
# 644    2.404907                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  6
# Variable excluded in this iteration: {'feature': 'eletricity', 'p-value': 0.21183262474694531}
# I-Distance rank:
#      I-Distance                    city
# 0      0.101214              Adamantina
# 1      8.676054                  Adolfo
# 2      2.049749                   Aguaí
# 3      0.317148          Águas da Prata
# 4      4.937437        Águas de Lindóia
# 5      2.958699  Águas de Santa Bárbara
# 6      3.772224      Águas de São Pedro
# 7      3.470894                  Agudos
# 8      2.028311                Alambari
# 9      4.140111       Alfredo Marcondes
# 10     1.799348                  Altair
# 11     3.055199             Altinópolis
# 12     5.733938             Alto Alegre
# 13     5.444543                Alumínio
# 14     6.831277        Álvares Florence
# 15     1.485004         Álvares Machado
# 16     3.944616      Álvaro de Carvalho
# 17     1.183438             Alvinlândia
# 18     1.719537               Americana
# 19     3.435814     Américo Brasiliense
# 20     0.236918       Américo de Campos
# 21     0.451299                  Amparo
# 22     0.774882               Analândia
# 23     0.274891               Andradina
# 24     0.904511                Angatuba
# 25     1.932087                 Anhembi
# 26     6.851063                 Anhumas
# 27     1.400277               Aparecida
# 28     1.324422       Aparecida d'Oeste
# 29     7.306355                   Apiaí
# ..          ...                     ...
# 615    1.672410                Tremembé
# 616    3.787361         Três Fronteiras
# 617    0.940634                  Tuiuti
# 618    0.161594                    Tupã
# 619    1.185933           Tupi Paulista
# 620    2.960304                 Turiúba
# 621    2.441609               Turmalina
# 622    3.426479                 Ubarana
# 623    3.811347                 Ubatuba
# 624    2.116203               Ubirajara
# 625    1.329258                   Uchoa
# 626    0.941316          União Paulista
# 627    0.273750                  Urânia
# 628    1.114951                     Uru
# 629    2.273737                  Urupês
# 630    0.844066         Valentim Gentil
# 631    1.001077                Valinhos
# 632    2.050615              Valparaíso
# 633    3.768929                  Vargem
# 634    2.098905    Vargem Grande do Sul
# 635    0.610947  Vargem Grande Paulista
# 636    0.584006         Várzea Paulista
# 637    2.354490               Vera Cruz
# 638    2.369016                 Vinhedo
# 639    0.431121               Viradouro
# 640    2.431525    Vista Alegre do Alto
# 641    0.853293          Vitória Brasil
# 642    3.182162              Votorantim
# 643    1.973998             Votuporanga
# 644    2.403179                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  7
# Variable excluded in this iteration: {'feature': 'jobs_revenue', 'p-value': 0.22217611889941577}
# I-Distance rank:
#      I-Distance                    city
# 0      0.097241              Adamantina
# 1      8.741788                  Adolfo
# 2      2.061760                   Aguaí
# 3      0.313830          Águas da Prata
# 4      4.972123        Águas de Lindóia
# 5      2.979665  Águas de Santa Bárbara
# 6      3.786064      Águas de São Pedro
# 7      3.494195                  Agudos
# 8      2.041441                Alambari
# 9      4.169836       Alfredo Marcondes
# 10     1.809525                  Altair
# 11     3.075841             Altinópolis
# 12     5.776565             Alto Alegre
# 13     5.484739                Alumínio
# 14     6.884522        Álvares Florence
# 15     1.492685         Álvares Machado
# 16     3.974953      Álvaro de Carvalho
# 17     1.188112             Alvinlândia
# 18     1.728064               Americana
# 19     3.458275     Américo Brasiliense
# 20     0.234992       Américo de Campos
# 21     0.452617                  Amparo
# 22     0.777322               Analândia
# 23     0.272319               Andradina
# 24     0.909170                Angatuba
# 25     1.945050                 Anhembi
# 26     6.902252                 Anhumas
# 27     1.405914               Aparecida
# 28     1.331263       Aparecida d'Oeste
# 29     7.362990                   Apiaí
# ..          ...                     ...
# 615    1.680765                Tremembé
# 616    3.813533         Três Fronteiras
# 617    0.947642                  Tuiuti
# 618    0.158067                    Tupã
# 619    1.192049           Tupi Paulista
# 620    2.980731                 Turiúba
# 621    2.458615               Turmalina
# 622    3.449218                 Ubarana
# 623    3.836844                 Ubatuba
# 624    2.130195               Ubirajara
# 625    1.335591                   Uchoa
# 626    0.945289          União Paulista
# 627    0.270465                  Urânia
# 628    1.117823                     Uru
# 629    2.287972                  Urupês
# 630    0.846499         Valentim Gentil
# 631    1.003362                Valinhos
# 632    2.061786              Valparaíso
# 633    3.798962                  Vargem
# 634    2.110454    Vargem Grande do Sul
# 635    0.610707  Vargem Grande Paulista
# 636    0.581856         Várzea Paulista
# 637    2.368097               Vera Cruz
# 638    2.382381                 Vinhedo
# 639    0.429605               Viradouro
# 640    2.445937    Vista Alegre do Alto
# 641    0.856730          Vitória Brasil
# 642    3.202645              Votorantim
# 643    1.984768             Votuporanga
# 644    2.419612                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  8
# Variable excluded in this iteration: {'feature': 'hosp_rooms', 'p-value': 0.2250198139122323}
# I-Distance rank:
#      I-Distance                    city
# 0      0.070026              Adamantina
# 1      8.922644                  Adolfo
# 2      2.080950                   Aguaí
# 3      0.275546          Águas da Prata
# 4      5.059123        Águas de Lindóia
# 5      3.030566  Águas de Santa Bárbara
# 6      3.716530      Águas de São Pedro
# 7      3.548275                  Agudos
# 8      2.069380                Alambari
# 9      4.246419       Alfredo Marcondes
# 10     1.817851                  Altair
# 11     3.125839             Altinópolis
# 12     5.889662             Alto Alegre
# 13     5.578403                Alumínio
# 14     7.037714        Álvares Florence
# 15     1.501533         Álvares Machado
# 16     4.060316      Álvaro de Carvalho
# 17     1.182815             Alvinlândia
# 18     1.731624               Americana
# 19     3.504319     Américo Brasiliense
# 20     0.216202       Américo de Campos
# 21     0.442364                  Amparo
# 22     0.768423               Analândia
# 23     0.247113               Andradina
# 24     0.909467                Angatuba
# 25     1.972540                 Anhembi
# 26     7.038574                 Anhumas
# 27     1.401682               Aparecida
# 28     1.338907       Aparecida d'Oeste
# 29     7.522748                   Apiaí
# ..          ...                     ...
# 615    1.682578                Tremembé
# 616    3.873272         Três Fronteiras
# 617    0.960859                  Tuiuti
# 618    0.133199                    Tupã
# 619    1.196678           Tupi Paulista
# 620    3.029620                 Turiúba
# 621    2.498028               Turmalina
# 622    3.495866                 Ubarana
# 623    3.895695                 Ubatuba
# 624    2.159283               Ubirajara
# 625    1.339243                   Uchoa
# 626    0.941694          União Paulista
# 627    0.234404                  Urânia
# 628    1.097479                     Uru
# 629    2.318703                  Urupês
# 630    0.841005         Valentim Gentil
# 631    0.977239                Valinhos
# 632    2.071018              Valparaíso
# 633    3.884777                  Vargem
# 634    2.125115    Vargem Grande do Sul
# 635    0.588211  Vargem Grande Paulista
# 636    0.538869         Várzea Paulista
# 637    2.384660               Vera Cruz
# 638    2.393773                 Vinhedo
# 639    0.410504               Viradouro
# 640    2.460900    Vista Alegre do Alto
# 641    0.855177          Vitória Brasil
# 642    3.239959              Votorantim
# 643    1.998963             Votuporanga
# 644    2.458523                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  9
# Variable excluded in this iteration: {'feature': 'urban_pop', 'p-value': 0.22552916604204629}
# I-Distance rank:
#      I-Distance                    city
# 0      0.071226              Adamantina
# 1      8.931473                  Adolfo
# 2      2.084079                   Aguaí
# 3      0.277701          Águas da Prata
# 4      5.064871        Águas de Lindóia
# 5      3.034030  Águas de Santa Bárbara
# 6      3.725721      Águas de São Pedro
# 7      3.552594                  Agudos
# 8      2.072091                Alambari
# 9      4.251097       Alfredo Marcondes
# 10     1.820837                  Altair
# 11     3.129588             Altinópolis
# 12     5.895737             Alto Alegre
# 13     5.584540                Alumínio
# 14     7.044205        Álvares Florence
# 15     1.504040         Álvares Machado
# 16     4.064190      Álvaro de Carvalho
# 17     1.185324             Alvinlândia
# 18     1.734147               Americana
# 19     3.508736     Américo Brasiliense
# 20     0.217526       Américo de Campos
# 21     0.443378                  Amparo
# 22     0.770276               Analândia
# 23     0.248656               Andradina
# 24     0.911110                Angatuba
# 25     1.975041                 Anhembi
# 26     7.045790                 Anhumas
# 27     1.404510               Aparecida
# 28     1.341146       Aparecida d'Oeste
# 29     7.529815                   Apiaí
# ..          ...                     ...
# 615    1.685627                Tremembé
# 616    3.877922         Três Fronteiras
# 617    0.961982                  Tuiuti
# 618    0.133923                    Tupã
# 619    1.198714           Tupi Paulista
# 620    3.033221                 Turiúba
# 621    2.500994               Turmalina
# 622    3.500381                 Ubarana
# 623    3.900449                 Ubatuba
# 624    2.162067               Ubirajara
# 625    1.341691                   Uchoa
# 626    0.943638          União Paulista
# 627    0.236363                  Urânia
# 628    1.100396                     Uru
# 629    2.321799                  Urupês
# 630    0.842966         Valentim Gentil
# 631    0.979952                Valinhos
# 632    2.074444              Valparaíso
# 633    3.888251                  Vargem
# 634    2.128458    Vargem Grande do Sul
# 635    0.590348  Vargem Grande Paulista
# 636    0.541627         Várzea Paulista
# 637    2.388388               Vera Cruz
# 638    2.397604                 Vinhedo
# 639    0.412237               Viradouro
# 640    2.464755    Vista Alegre do Alto
# 641    0.856937          Vitória Brasil
# 642    3.244258              Votorantim
# 643    2.001970             Votuporanga
# 644    2.461491                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  10
# Variable excluded in this iteration: {'feature': 'population', 'p-value': 0.22677585892468219}
# I-Distance rank:
#      I-Distance                    city
# 0      0.071025              Adamantina
# 1      8.931208                  Adolfo
# 2      2.083854                   Aguaí
# 3      0.277466          Águas da Prata
# 4      5.064564        Águas de Lindóia
# 5      3.033884  Águas de Santa Bárbara
# 6      3.725401      Águas de São Pedro
# 7      3.552380                  Agudos
# 8      2.071931                Alambari
# 9      4.250864       Alfredo Marcondes
# 10     1.820637                  Altair
# 11     3.129419             Altinópolis
# 12     5.895540             Alto Alegre
# 13     5.584358                Alumínio
# 14     7.044074        Álvares Florence
# 15     1.503865         Álvares Machado
# 16     4.064112      Álvaro de Carvalho
# 17     1.185058             Alvinlândia
# 18     1.733890               Americana
# 19     3.508436     Américo Brasiliense
# 20     0.217316       Américo de Campos
# 21     0.442571                  Amparo
# 22     0.770083               Analândia
# 23     0.248389               Andradina
# 24     0.910757                Angatuba
# 25     1.974899                 Anhembi
# 26     7.045572                 Anhumas
# 27     1.404227               Aparecida
# 28     1.340934       Aparecida d'Oeste
# 29     7.529456                   Apiaí
# ..          ...                     ...
# 615    1.685354                Tremembé
# 616    3.877704         Três Fronteiras
# 617    0.961914                  Tuiuti
# 618    0.133709                    Tupã
# 619    1.198531           Tupi Paulista
# 620    3.032989                 Turiúba
# 621    2.500812               Turmalina
# 622    3.500120                 Ubarana
# 623    3.900259                 Ubatuba
# 624    2.161926               Ubirajara
# 625    1.341436                   Uchoa
# 626    0.943427          União Paulista
# 627    0.236181                  Urânia
# 628    1.100126                     Uru
# 629    2.321596                  Urupês
# 630    0.842735         Valentim Gentil
# 631    0.979568                Valinhos
# 632    2.074195              Valparaíso
# 633    3.888097                  Vargem
# 634    2.128270    Vargem Grande do Sul
# 635    0.590028  Vargem Grande Paulista
# 636    0.541306         Várzea Paulista
# 637    2.388194               Vera Cruz
# 638    2.397411                 Vinhedo
# 639    0.411961               Viradouro
# 640    2.464492    Vista Alegre do Alto
# 641    0.856692          Vitória Brasil
# 642    3.243934              Votorantim
# 643    2.001756             Votuporanga
# 644    2.461274                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  11
# Variable excluded in this iteration: {'feature': 'import', 'p-value': 0.26913827924733252}
# I-Distance rank:
#      I-Distance                    city
# 0      0.070820              Adamantina
# 1      8.941918                  Adolfo
# 2      2.087875                   Aguaí
# 3      0.288771          Águas da Prata
# 4      5.070185        Águas de Lindóia
# 5      3.038597  Águas de Santa Bárbara
# 6      3.803940      Águas de São Pedro
# 7      3.555746                  Agudos
# 8      2.076092                Alambari
# 9      4.255221       Alfredo Marcondes
# 10     1.830687                  Altair
# 11     3.131829             Altinópolis
# 12     5.904989             Alto Alegre
# 13     5.596922                Alumínio
# 14     7.051091        Álvares Florence
# 15     1.505515         Álvares Machado
# 16     4.068516      Álvaro de Carvalho
# 17     1.190411             Alvinlândia
# 18     1.737814               Americana
# 19     3.514249     Américo Brasiliense
# 20     0.218232       Américo de Campos
# 21     0.442949                  Amparo
# 22     0.774919               Analândia
# 23     0.250192               Andradina
# 24     0.915256                Angatuba
# 25     1.977245                 Anhembi
# 26     7.057353                 Anhumas
# 27     1.409236               Aparecida
# 28     1.343859       Aparecida d'Oeste
# 29     7.537741                   Apiaí
# ..          ...                     ...
# 615    1.693436                Tremembé
# 616    3.886417         Três Fronteiras
# 617    0.967240                  Tuiuti
# 618    0.132986                    Tupã
# 619    1.202784           Tupi Paulista
# 620    3.036848                 Turiúba
# 621    2.506076               Turmalina
# 622    3.508428                 Ubarana
# 623    3.905612                 Ubatuba
# 624    2.168263               Ubirajara
# 625    1.342418                   Uchoa
# 626    0.949113          União Paulista
# 627    0.247738                  Urânia
# 628    1.113960                     Uru
# 629    2.322920                  Urupês
# 630    0.842774         Valentim Gentil
# 631    0.990937                Valinhos
# 632    2.081380              Valparaíso
# 633    3.893492                  Vargem
# 634    2.134085    Vargem Grande do Sul
# 635    0.591973  Vargem Grande Paulista
# 636    0.554303         Várzea Paulista
# 637    2.399708               Vera Cruz
# 638    2.407307                 Vinhedo
# 639    0.411812               Viradouro
# 640    2.474588    Vista Alegre do Alto
# 641    0.856792          Vitória Brasil
# 642    3.251838              Votorantim
# 643    2.005084             Votuporanga
# 644    2.462870                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  12
# Variable excluded in this iteration: {'feature': 'industry_add', 'p-value': 0.30475279982672204}
# I-Distance rank:
#      I-Distance                    city
# 0      0.070859              Adamantina
# 1      8.946048                  Adolfo
# 2      2.088822                   Aguaí
# 3      0.288763          Águas da Prata
# 4      5.072528        Águas de Lindóia
# 5      3.039988  Águas de Santa Bárbara
# 6      3.804715      Águas de São Pedro
# 7      3.557403                  Agudos
# 8      2.077030                Alambari
# 9      4.257197       Alfredo Marcondes
# 10     1.831432                  Altair
# 11     3.133296             Altinópolis
# 12     5.907686             Alto Alegre
# 13     5.599426                Alumínio
# 14     7.054365        Álvares Florence
# 15     1.506215         Álvares Machado
# 16     4.070400      Álvaro de Carvalho
# 17     1.190912             Alvinlândia
# 18     1.738553               Americana
# 19     3.515847     Américo Brasiliense
# 20     0.218328       Américo de Campos
# 21     0.443154                  Amparo
# 22     0.775229               Analândia
# 23     0.250291               Andradina
# 24     0.915635                Angatuba
# 25     1.978160                 Anhembi
# 26     7.060570                 Anhumas
# 27     1.409840               Aparecida
# 28     1.344465       Aparecida d'Oeste
# 29     7.541231                   Apiaí
# ..          ...                     ...
# 615    1.694136                Tremembé
# 616    3.888160         Três Fronteiras
# 617    0.967631                  Tuiuti
# 618    0.133061                    Tupã
# 619    1.203304           Tupi Paulista
# 620    3.038250                 Turiúba
# 621    2.507204               Turmalina
# 622    3.509997                 Ubarana
# 623    3.907408                 Ubatuba
# 624    2.169216               Ubirajara
# 625    1.343050                   Uchoa
# 626    0.949493          União Paulista
# 627    0.247707                  Urânia
# 628    1.114314                     Uru
# 629    2.324015                  Urupês
# 630    0.843178         Valentim Gentil
# 631    0.991244                Valinhos
# 632    2.082284              Valparaíso
# 633    3.895278                  Vargem
# 634    2.135029    Vargem Grande do Sul
# 635    0.592206  Vargem Grande Paulista
# 636    0.554318         Várzea Paulista
# 637    2.400705               Vera Cruz
# 638    2.408308                 Vinhedo
# 639    0.412013               Viradouro
# 640    2.475639    Vista Alegre do Alto
# 641    0.857203          Vitória Brasil
# 642    3.253274              Votorantim
# 643    2.005997             Votuporanga
# 644    2.464028                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  13
# Variable excluded in this iteration: {'feature': 'jobs', 'p-value': 0.31748957531347155}
# I-Distance rank:
#      I-Distance                    city
# 0      0.071110              Adamantina
# 1      8.889395                  Adolfo
# 2      2.076659                   Aguaí
# 3      0.291234          Águas da Prata
# 4      5.040712        Águas de Lindóia
# 5      3.021317  Águas de Santa Bárbara
# 6      3.805629      Águas de São Pedro
# 7      3.535112                  Agudos
# 8      2.064748                Alambari
# 9      4.230281       Alfredo Marcondes
# 10     1.822836                  Altair
# 11     3.113459             Altinópolis
# 12     5.871128             Alto Alegre
# 13     5.566051                Alumínio
# 14     7.009006        Álvares Florence
# 15     1.497218         Álvares Machado
# 16     4.044403      Álvaro de Carvalho
# 17     1.185281             Alvinlândia
# 18     1.728939               Americana
# 19     3.494700     Américo Brasiliense
# 20     0.217762       Américo de Campos
# 21     0.440825                  Amparo
# 22     0.772090               Analândia
# 23     0.249967               Andradina
# 24     0.911308                Angatuba
# 25     1.965939                 Anhembi
# 26     7.016985                 Anhumas
# 27     1.402751               Aparecida
# 28     1.336867       Aparecida d'Oeste
# 29     7.493106                   Apiaí
# ..          ...                     ...
# 615    1.685994                Tremembé
# 616    3.865196         Três Fronteiras
# 617    0.962841                  Tuiuti
# 618    0.132744                    Tupã
# 619    1.197025           Tupi Paulista
# 620    3.019411                 Turiúba
# 621    2.492272               Turmalina
# 622    3.489579                 Ubarana
# 623    3.883407                 Ubatuba
# 624    2.156948               Ubirajara
# 625    1.334995                   Uchoa
# 626    0.945396          União Paulista
# 627    0.250462                  Urânia
# 628    1.111981                     Uru
# 629    2.309344                  Urupês
# 630    0.838186         Valentim Gentil
# 631    0.989073                Valinhos
# 632    2.071308              Valparaíso
# 633    3.870619                  Vargem
# 634    2.123218    Vargem Grande do Sul
# 635    0.589732  Vargem Grande Paulista
# 636    0.555827         Várzea Paulista
# 637    2.388825               Vera Cruz
# 638    2.396030                 Vinhedo
# 639    0.409987               Viradouro
# 640    2.462876    Vista Alegre do Alto
# 641    0.852010          Vitória Brasil
# 642    3.234561              Votorantim
# 643    1.994273             Votuporanga
# 644    2.448326                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  14
# Variable excluded in this iteration: {'feature': 'value_add', 'p-value': 0.32161400038777122}
# I-Distance rank:
#      I-Distance                    city
# 0      0.070540              Adamantina
# 1      8.924365                  Adolfo
# 2      2.083880                   Aguaí
# 3      0.289316          Águas da Prata
# 4      5.060171        Águas de Lindóia
# 5      3.032716  Águas de Santa Bárbara
# 6      3.804731      Águas de São Pedro
# 7      3.548599                  Agudos
# 8      2.072157                Alambari
# 9      4.246736       Alfredo Marcondes
# 10     1.827910                  Altair
# 11     3.125478             Altinópolis
# 12     5.893651             Alto Alegre
# 13     5.586609                Alumínio
# 14     7.037129        Álvares Florence
# 15     1.502460         Álvares Machado
# 16     4.060491      Álvaro de Carvalho
# 630    0.842563         Valentim Gentil
# 631    1.009358                Valinhos
# 632    2.091778              Valparaíso
# 633    3.898837                  Vargem
# 634    2.142213    Vargem Grande do Sul
# 635    0.595513  Vargem Grande Paulista
# 636    0.576598         Várzea Paulista
# 637    2.416778               Vera Cruz
# 638    2.422079                 Vinhedo
# 639    0.411746               Viradouro
# 640    2.489345    Vista Alegre do Alto
# 641    0.856573          Vitória Brasil
# 642    3.262501              Votorantim
# 643    2.009296             Votuporanga
# 644    2.463594                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  16
# Variable excluded in this iteration: {'feature': 'violence', 'p-value': 0.35148011010200286}
# I-Distance rank:
#      I-Distance                    city
# 0      0.072072              Adamantina
# 1      9.210487                  Adolfo
# 2      2.150723                   Aguaí
# 3      0.301500          Águas da Prata
# 4      5.221801        Águas de Lindóia
# 5      3.130112  Águas de Santa Bárbara
# 6      3.949409      Águas de São Pedro
# 7      3.661678                  Agudos
# 8      2.138867                Alambari
# 9      4.382421       Alfredo Marcondes
# 10     1.888683                  Altair
# 11     3.224929             Altinópolis
# 12     6.083304             Alto Alegre
# 13     5.767376                Alumínio
# 14     7.262465        Álvares Florence
# 15     1.550104         Álvares Machado
# 16     4.190569      Álvaro de Carvalho
# 17     1.227260             Alvinlândia
# 18     1.789891               Americana
# 19     3.619901     Américo Brasiliense
# 20     0.224496       Américo de Campos
# 21     0.455688                  Amparo
# 22     0.799417               Analândia
# 23     0.257655               Andradina
# 24     0.943906                Angatuba
# 25     2.036333                 Anhembi
# 26     7.270729                 Anhumas
# 27     1.452245               Aparecida
# 28     1.384323       Aparecida d'Oeste
# 29     7.764003                   Apiaí
# ..          ...                     ...
# 615    1.746312                Tremembé
# 616    4.004581         Três Fronteiras
# 617    0.998128                  Tuiuti
# 618    0.135853                    Tupã
# 619    1.239732           Tupi Paulista
# 620    3.127835                 Turiúba
# 621    2.582124               Turmalina
# 622    3.615137                 Ubarana
# 623    4.022696                 Ubatuba
# 624    2.234768               Ubirajara
# 625    1.381849                   Uchoa
# 626    0.979179          União Paulista
# 627    0.259459                  Urânia
# 628    1.152217                     Uru
# 629    2.391579                  Urupês
# 630    0.867025         Valentim Gentil
# 631    1.024296                Valinhos
# 632    2.145325              Valparaíso
# 633    4.010957                  Vargem
# 634    2.198983    Vargem Grande do Sul
# 635    0.609362  Vargem Grande Paulista
# 636    0.575069         Várzea Paulista
# 637    2.475043               Vera Cruz
# 638    2.481922                 Vinhedo
# 639    0.423144               Viradouro
# 640    2.551439    Vista Alegre do Alto
# 641    0.881600          Vitória Brasil
# 642    3.350623              Votorantim
# 643    2.065046             Votuporanga
# 644    2.535931                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  17
# Variable excluded in this iteration: {'feature': 'pub_inv', 'p-value': 0.35783468355125547}
# I-Distance rank:
#      I-Distance                    city
# 0      0.071592              Adamantina
# 1      9.223588                  Adolfo
# 2      2.157600                   Aguaí
# 3      0.328858          Águas da Prata
# 4      5.228253        Águas de Lindóia
# 5      3.137224  Águas de Santa Bárbara
# 6      4.136376      Águas de São Pedro
# 7      3.664786                  Agudos
# 8      2.146055                Alambari
# 9      4.386881       Alfredo Marcondes
# 10     1.910664                  Altair
# 11     3.226303             Altinópolis
# 12     6.097785             Alto Alegre
# 13     5.790002                Alumínio
# 14     7.269271        Álvares Florence
# 15     1.552031         Álvares Machado
# 16     4.195379      Álvaro de Carvalho
# 17     1.238702             Alvinlândia
# 18     1.797486               Americana
# 19     3.629127     Américo Brasiliense
# 20     0.226498       Américo de Campos
# 21     0.456028                  Amparo
# 22     0.810184               Analândia
# 23     0.261819               Andradina
# 24     0.953618                Angatuba
# 25     2.039217                 Anhembi
# 26     7.289226                 Anhumas
# 27     1.462610               Aparecida
# 28     1.389575       Aparecida d'Oeste
# 29     7.773215                   Apiaí
# ..          ...                     ...
# 615    1.763745                Tremembé
# 616    4.020259         Três Fronteiras
# 617    1.009758                  Tuiuti
# 618    0.134025                    Tupã
# 619    1.248448           Tupi Paulista
# 620    3.132864                 Turiúba
# 621    2.591356               Turmalina
# 622    3.630393                 Ubarana
# 623    4.030170                 Ubatuba
# 624    2.247134               Ubirajara
# 625    1.382374                   Uchoa
# 626    0.991760          União Paulista
# 627    0.287488                  Urânia
# 628    1.184533                     Uru
# 629    2.391492                  Urupês
# 630    0.865984         Valentim Gentil
# 631    1.050970                Valinhos
# 632    2.159966              Valparaíso
# 633    4.018430                  Vargem
# 634    2.210217    Vargem Grande do Sul
# 635    0.613652  Vargem Grande Paulista
# 636    0.607060         Várzea Paulista
# 637    2.499785               Vera Cruz
# 638    2.502934                 Vinhedo
# 639    0.422292               Viradouro
# 640    2.572618    Vista Alegre do Alto
# 641    0.880656          Vitória Brasil
# 642    3.365431              Votorantim
# 643    2.070394             Votuporanga
# 644    2.536267                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  18
# Variable excluded in this iteration: {'feature': 'primary_enrolls', 'p-value': 0.39304955119470286}
# I-Distance rank:
#      I-Distance                    city
# 0      0.072818              Adamantina
# 1      9.211975                  Adolfo
# 2      2.148034                   Aguaí
# 3      0.279133          Águas da Prata
# 4      5.223634        Águas de Lindóia
# 5      3.128449  Águas de Santa Bárbara
# 6      3.797886      Águas de São Pedro
# 7      3.664192                  Agudos
# 8      2.135827                Alambari
# 9      4.384711       Alfredo Marcondes
# 10     1.872896                  Altair
# 11     3.228277             Altinópolis
# 12     6.079409             Alto Alegre
# 13     5.756253                Alumínio
# 14     7.266533        Álvares Florence
# 15     1.550771         Álvares Machado
# 16     4.192195      Álvaro de Carvalho
# 17     1.219502             Alvinlândia
# 18     1.786337               Americana
# 19     3.617267     Américo Brasiliense
# 20     0.223302       Américo de Campos
# 21     0.456215                  Amparo
# 22     0.791602               Analândia
# 23     0.254736               Andradina
# 24     0.937134                Angatuba
# 25     2.036765                 Anhembi
# 26     7.265058                 Anhumas
# 27     1.445762               Aparecida
# 28     1.381936       Aparecida d'Oeste
# 29     7.766753                   Apiaí
# ..          ...                     ...
# 615    1.734236                Tremembé
# 616    3.996941         Três Fronteiras
# 617    0.989702                  Tuiuti
#
# [645 rows x 2 columns]
# Iteration of Number:  20
# Variable excluded in this iteration: {'feature': 'agriculture_add', 'p-value': 0.58311115678463787}
# I-Distance rank:
#      I-Distance                    city
# 0      0.102403              Adamantina
# 1      9.065549                  Adolfo
# 2      2.111433                   Aguaí
# 3      0.146105          Águas da Prata
# 4      5.161834        Águas de Lindóia
# 5      3.071493  Águas de Santa Bárbara
# 6      2.731298      Águas de São Pedro
# 7      3.635902                  Agudos
# 8      2.089413                Alambari
# 9      4.335205       Alfredo Marcondes
# 10     1.747840                  Altair
# 11     3.210206             Altinópolis
# 12     5.952188             Alto Alegre
# 13     5.588237                Alumínio
# 14     7.163426        Álvares Florence
# 15     1.548239         Álvares Machado
# 16     4.129834      Álvaro de Carvalho
# 17     1.166711             Alvinlândia
# 18     1.754744               Americana
# 19     3.556866     Américo Brasiliense
# 20     0.231140       Américo de Campos
# 21     0.467797                  Amparo
# 22     0.741248               Analândia
# 23     0.255164               Andradina
# 24     0.886235                Angatuba
# 25     2.015251                 Anhembi
# 26     7.104400                 Anhumas
# 27     1.401466               Aparecida
# 28     1.358213       Aparecida d'Oeste
# 29     7.648016                   Apiaí
# ..          ...                     ...
# 615    1.642431                Tremembé
# 616    3.888089         Três Fronteiras
# 617    0.914571                  Tuiuti
# 618    0.174814                    Tupã
# 619    1.189403           Tupi Paulista
# 620    3.086458                 Turiúba
# 621    2.512440               Turmalina
# 622    3.508543                 Ubarana
# 623    3.966342                 Ubatuba
# 624    2.148298               Ubirajara
# 625    1.392355                   Uchoa
# 626    0.905702          União Paulista
# 627    0.097035                  Urânia
# 628    0.956235                     Uru
# 629    2.394763                  Urupês
# 630    0.891564         Valentim Gentil
# 631    0.869759                Valinhos
# 632    2.058968              Valparaíso
# 633    3.928111                  Vargem
# 634    2.133779    Vargem Grande do Sul
# 635    0.606756  Vargem Grande Paulista
# 636    0.393452         Várzea Paulista
# 637    2.315110               Vera Cruz
# 638    2.351684                 Vinhedo
# 639    0.453698               Viradouro
# 640    2.417087    Vista Alegre do Alto
# 641    0.901081          Vitória Brasil
# 642    3.252041              Votorantim
# 643    2.040340             Votuporanga
# 644    2.529407                Zacarias
#
# [645 rows x 2 columns]
# Iterations needed:  20

# %%
rank2.sort_values("r", ascending=False)
# Out:
#        feature       p-value         r
# 1   gdp_growth  2.519221e-61  0.588352
# 0      gdp_per  1.639504e-08  0.220019
# 2  density_pop  3.476726e-02 -0.083140
# 3       urbing  7.199990e-05 -0.155650

# %% [markdown]
# As we can see, <b>using the normal form of the formula is not a good idea </b> once the variables are at most droped due to big differences in the discriminate effects.

# %% [markdown]
# # Working with clusters

# %% [markdown]
# <h4> Building the elbow method to choose optimized numbers of clusters

# %%
from sklearn.cluster import KMeans
import numpy as np
from scipy.spatial.distance import cdist, pdist
from sklearn.decomposition import PCA

dataf = data_values.drop('city', 1)  # dropping the city column


# 2. Creating the matrix
x_cols = dataf.as_matrix(columns= list(dataf.columns))

# 3. Applying KMeans to the matrix
kmeans = KMeans().fit(x_cols)

# k values to test for
ktest = list(range(2,11)) 

# Fitting the Kmeans for the all the test values for different k`s
k_means_runs = [KMeans(n_clusters=k).fit(x_cols) for k in ktest]

# Taking the cluster centroids position
centroids = [cent.cluster_centers_ for cent in k_means_runs]


# Calculating the Euclidian distance from each cluster point to its correspondent centroid
k_dist = [cdist(x_cols, cent, 'euclidean') for cent in centroids]
dist = [np.min(ke, axis=1) for ke in k_dist]

# Distance within clusters
ss = [sum(d**2) for d in dist]


# Ploting
plt.plot(ktest, ss)
#plt.ylim((0,255))
plt.xlabel('n_clusters')
plt.ylabel('Total Variance whithin cluster')
plt.title('Variance Explained vs. k')

# %% [markdown]
# Using the Elbow Method, is clear to see that beginning from k =5 , the variance explained declines is a smaller rate, so our <b>optimal k for this case would be 5.

# %% [markdown]
# <h4> Calculating the clusters

# %% [markdown]
# It looks like we have two data points, forming two different clusters, that are isolated.

# %%
# getting the final model for the clusters with k=5

k_final = KMeans(n_clusters=5).fit(x_cols)

clabels = k_final.labels_

unique, counts = np.unique(clabels, return_counts=True)
label_count = {}
for x,y in zip(unique, counts):
    label_count[x] = y

print("Label countdown: ", label_count)


## Building some scatter plot to visualize the clusters

# getting the PCA components
pca = PCA(n_components=2)
x_cols_2 = pca.fit_transform(x_cols)

x, y = x_cols_2[:,0], x_cols_2[:,1]

# building the dataframe
l = list(range(1,33))
datac = pd.DataFrame()
datac['x'] = x
datac['y'] = y
datac['cluster_id'] = clabels
datac = datac.reset_index()

# ploting the scatter
sns.lmplot('x', 'y',  datac, hue='cluster_id' ,fit_reg=False, size=6)
# Out:
# Label countdown:  {0: 629, 1: 1, 2: 11, 3: 1, 4: 3}

# %% [markdown]
# Identifying the most representative cities for the cluster centroids:

# %%
min_dist = np.min(cdist(x_cols,k_final.cluster_centers_, 'euclidean'), axis=1) #calculating min distance between cities 
Y = pd.DataFrame(min_dist,index=dataf.index, columns=['distance'])              # and centroids
Z = pd.DataFrame(k_final.labels_,index=dataf.index, columns=['labels'])

YZ = pd.concat([Y,Z], axis=1)

grouped = YZ.groupby(['labels']) #grouping the distances by label so we can select the minimum one
grouped.idxmin()
# Out:
#         distance
# labels
# 0           7748
# 1           9601
# 2          10315
# 3           9669
# 4           9516

# %%
print("Representant of cluster 0 : ", data_values.loc[grouped.idxmin().distance[0]].city)
print("Representant of cluster 1 : ", data_values.loc[grouped.idxmin().distance[1]].city)
print("Representant of cluster 2 : ", data_values.loc[grouped.idxmin().distance[2]].city)
print("Representant of cluster 3 : ", data_values.loc[grouped.idxmin().distance[3]].city)
print("Representant of cluster 4 : ", data_values.loc[grouped.idxmin().distance[4]].city)
# Out:
# Representant of cluster 0 :  Porto Feliz
# Representant of cluster 1 :  São Paulo
# Representant of cluster 2 :  Taubaté
# Representant of cluster 3 :  São Sebastião
# Representant of cluster 4 :  São José dos Campos

# %% [markdown]
# <h4> Checking the I-Distance with the Cluster Labels

# %% [markdown]
# Inputing the cluster labels into the base

# %%
data_clust = data_values
data_clust['cluster'] = clabels  # including cluster labels to the dataset

col = list(data_clust.columns)
col = col[0:1] + col[-1:] + col[1:25]  # reordering the columns of the dataset to facilitate the function flow

data_clust = data_clust.reindex_axis(col, axis = 1) #reindexing the Dataframe

# %% [markdown]
# Getting the reference hyperplane

# %%
reference = data_clust.sort_values('gdp_per', ascending=True).iloc[0:1,:]

# %% [markdown]
# Changing the function to input the cluster labels to the rank

# %%
def I_distance(data_values, reference):
    # getting the correlation matrix done
    data_corr = data_values.drop(['city', 'cluster'] ,1).fillna(0)
    col_labels = list(data_corr.columns)
    corre = pd.DataFrame(partial_corr(data_corr), columns=col_labels)
                         
    #starting the I-Distance calculation                     
    ncolums = data_corr.shape[1]
    nrows = data_corr.shape[0]
    somatory = []
    i2_index = {'city': [], 'I-Distance': [], 'Cluster': []}
    for r in range(0,nrows):
        somatory = []    
        for i in range(0,ncolums):
            prod = 1
            summ_1 = 0
            summ_1 = ((data_corr.iloc[r,i] - reference.iloc[0,i+2])**2)/np.var(data_corr.iloc[:,i]) #distance squared divided by variance
            for k in range(i+1):
                if corre.iloc[i,k] == 1:
                    prod *= 1
                else:
                    prod *= (1-(corre.iloc[i,k])**2)
            somatory.append(summ_1*prod)
        i2_index['city'].append(data_values.iloc[r,0])
        i2_index['Cluster'].append(data_values.iloc[r,1]) ## ADDITION - adding the cluster label to the distance frame!!
        i2_index['I-Distance'].append(np.cumsum(somatory)[-1])
    

## 5 - 6 selecting sigficant features

# calculating the rank of features and p-values

    distance = pd.DataFrame(i2_index)

    data = data_values.iloc[:,1:]
    feature_rank = {'feature': [], 'r': [], 'p-value': []}

    # creating the rank with correlation, p-values and name of features
    for col, values in data.iteritems():
        feature_rank['feature'].append(col)
        feature_rank['r'].append(stats.pearsonr(values, distance['I-Distance'])[0])
        feature_rank['p-value'].append(stats.pearsonr(values, distance['I-Distance'])[1])
    

    # manipulating the rank to select smallest correlation value with no significant p-value valor (>0.01)
    rank = pd.DataFrame(feature_rank)
    lenght_rank = len(list(rank.columns))
  
    excluded = {'feature' : "" , 'p-value' : 0 }
    for x in range(lenght_rank):
        excluded = {'feature' : "" , 'p-value' : 0 }
        chk = 0
        if rank.sort_values('r').iloc[x,1] >= 0.05 and x <= lenght_rank:  # check if the smallest r value is significant
            excluded['feature'] = rank.sort_values('r').iloc[x,0]
            excluded['p-value'] = rank.sort_values('r').iloc[x,1]
            chk = 1
            break
        elif rank.sort_values('r').iloc[x,1] <= 0.05 and x == lenght_rank:
            chk = 0
            break
        else:
            chk = 0
            continue
    if chk == 1: # returning new data frame if there is some variable to exclude, otherwise is done
        n_values = data_values.drop(excluded['feature'], 1)
        n_ref = reference.drop(excluded['feature'], 1)
        return 'loop',distance,  n_values, n_ref, excluded
    else:
        return 'done', distance, rank, 'ref', excluded # if no features to drop, return distance and rank

# %%
def Final_distance(data_values, reference):
    check, distance, rank, ref, excluded = I_distance(data_values, reference)
    
    cont=1
    while True:
        if check == 'loop':
            print("Iteration of Number: ", cont)
            print("Variable excluded in this iteration:", excluded )
            print("I-Distance rank:")
            print(distance)
            check, distance, rank, ref, excluded = I_distance(rank, ref)
            cont += 1
            continue
        else:
            print("Iterations needed: ", cont-1)
            break
    return check, distance, rank

# %% [markdown]
# Getting the I-Distance squared rank with cluster labels:

# %%
checkc, distancec, rankc = Final_distance(data_clust, reference)
# Out:
# Iteration of Number:  1
# Variable excluded in this iteration: {'feature': 'olding', 'p-value': 0.62152333001401172}
# I-Distance rank:
#      Cluster  I-Distance                    city
# 0          0   19.574375              Adamantina
# 1          0   12.623635                  Adolfo
# 2          0    7.619452                   Aguaí
# 3          0   14.912675          Águas da Prata
# 4          0   10.553639        Águas de Lindóia
# 5          0    4.973449  Águas de Santa Bárbara
# 6          0  175.278901      Águas de São Pedro
# 7          0   14.560906                  Agudos
# 8          0    2.860073                Alambari
# 9          0   13.647056       Alfredo Marcondes
# 10         0    7.707353                  Altair
# 11         0    9.946214             Altinópolis
# 12         0   16.617030             Alto Alegre
# 13         0   55.358300                Alumínio
# 14         0   20.329446        Álvares Florence
# 15         0    6.563823         Álvares Machado
# 16         0    1.786611      Álvaro de Carvalho
# 17         0    5.934405             Alvinlândia
# 18         0   24.343443               Americana
# 19         0   12.963261     Américo Brasiliense
# 20         0    8.488222       Américo de Campos
# 21         0   17.353354                  Amparo
# 22         0    5.603509               Analândia
# 23         0   14.095144               Andradina
# 24         0    6.805986                Angatuba
# 25         0    4.664807                 Anhembi
# 26         0    7.810902                 Anhumas
# 27         0    9.137248               Aparecida
# 28         0   15.335710       Aparecida d'Oeste
# 29         0   15.155430                   Apiaí
# ..       ...         ...                     ...
# 615        0    7.572549                Tremembé
# 616        0   11.985928         Três Fronteiras
# 617        0    6.288230                  Tuiuti
# 618        0   31.352973                    Tupã
# 619        0   16.739678           Tupi Paulista
# 620        0   14.743482                 Turiúba
# 621        0   20.412176               Turmalina
# 622        0   12.547339                 Ubarana
# 623        0    7.724365                 Ubatuba
# 624        0    3.258099               Ubirajara
# 625        0   11.290331                   Uchoa
# 626        0    4.647153          União Paulista
# 627        0   14.196895                  Urânia
# 628        0   12.986362                     Uru
# 629        0   11.955711                  Urupês
# 630        0    6.484321         Valentim Gentil
# 631        0   21.712239                Valinhos
# 632        0   15.234602              Valparaíso
# 633        0    2.670726                  Vargem
# 634        0    8.557061    Vargem Grande do Sul
# 635        0   13.193756  Vargem Grande Paulista
# 636        0   23.867952         Várzea Paulista
# 637        0    9.494356               Vera Cruz
# 638        0   36.151840                 Vinhedo
# 639        0    7.756703               Viradouro
# 640        0   16.947887    Vista Alegre do Alto
# 641        0    7.139492          Vitória Brasil
# 642        0   12.010807              Votorantim
# 643        0   12.373834             Votuporanga
# 644        0    7.056343                Zacarias
#
# [645 rows x 3 columns]
# Iteration of Number:  2
# Variable excluded in this iteration: {'feature': 'agriculture_add', 'p-value': 0.98214452581462652}
# I-Distance rank:
#      Cluster  I-Distance                    city
# 0          0   12.565135              Adamantina
# 1          0    8.237832                  Adolfo
# 2          0    6.473223                   Aguaí
# 3          0    7.944431          Águas da Prata
# 4          0    7.474909        Águas de Lindóia
# 5          0    3.257135  Águas de Santa Bárbara
# 6          0  153.321597      Águas de São Pedro
# 7          0   13.165581                  Agudos
# 628        0    8.394868                     Uru
# 629        0    4.562016                  Urupês
# 630        0    4.576849         Valentim Gentil
# 631        0   19.178361                Valinhos
# 632        0   10.272428              Valparaíso
# 633        0    0.323254                  Vargem
# 634        0    6.109250    Vargem Grande do Sul
# 635        0   11.752717  Vargem Grande Paulista
# 636        0   22.591595         Várzea Paulista
# 637        0    6.010498               Vera Cruz
# 638        0   34.123638                 Vinhedo
# 639        0    5.619110               Viradouro
# 640        0   15.200454    Vista Alegre do Alto
# 641        0    3.337205          Vitória Brasil
# 642        0   10.458604              Votorantim
# 643        0    7.813758             Votuporanga
# 644        0    3.614522                Zacarias
#
# [645 rows x 3 columns]
# Iteration of Number:  5
# Variable excluded in this iteration: {'feature': 'primary_enrolls', 'p-value': 0.20131162083727402}
# I-Distance rank:
#      Cluster  I-Distance                    city
# 0          0    5.797765              Adamantina
# 1          0    5.065967                  Adolfo
# 2          0    4.937450                   Aguaí
# 3          0    8.065789          Águas da Prata
# 4          0    6.096651        Águas de Lindóia
# 5          0    2.798153  Águas de Santa Bárbara
# 6          0  155.508127      Águas de São Pedro
# 7          0   10.753398                  Agudos
# 8          0    2.007895                Alambari
# 9          0    3.471201       Alfredo Marcondes
# 10         0    6.055808                  Altair
# 11         0    4.011196             Altinópolis
# 12         0    3.136352             Alto Alegre
# 13         0   53.386888                Alumínio
# 14         0    1.800728        Álvares Florence
# 15         0    4.316100         Álvares Machado
# 16         0    0.664901      Álvaro de Carvalho
# 17         0    4.722496             Alvinlândia
# 18         0   20.621770               Americana
# 19         0    8.345475     Américo Brasiliense
# 20         0    3.065581       Américo de Campos
# 21         0    7.951003                  Amparo
# 22         0    4.104494               Analândia
# 23         0    7.385984               Andradina
# 24         0    3.109510                Angatuba
# 25         0    3.674090                 Anhembi
# 26         0    4.004755                 Anhumas
# 27         0    6.746526               Aparecida
# 28         0    2.835838       Aparecida d'Oeste
# 29         0    2.603190                   Apiaí
# ..       ...         ...                     ...
# 615        0    6.415927                Tremembé
# 616        0    4.405875         Três Fronteiras
# 617        0    1.491593                  Tuiuti
# 618        0    6.064344                    Tupã
# 619        0    2.533077           Tupi Paulista
# 620        0    2.878626                 Turiúba
# 621        0    1.859344               Turmalina
# 622        0   11.019952                 Ubarana
# 623        0    5.967525                 Ubatuba
# 624        0    1.886336               Ubirajara
# 625        0    5.983672                   Uchoa
# 626        0    3.225402          União Paulista
# 627        0    6.921790                  Urânia
# 628        0    8.477158                     Uru
# 629        0    4.011759                  Urupês
# 630        0    4.665821         Valentim Gentil
# 631        0   19.046796                Valinhos
# 632        0    9.848543              Valparaíso
# 633        0    0.323617                  Vargem
# 634        0    5.874743    Vargem Grande do Sul
# 635        0   11.857846  Vargem Grande Paulista
# 636        0   22.677522         Várzea Paulista
# 637        0    6.084709               Vera Cruz
# 638        0   34.029307                 Vinhedo
# 639        0    5.060882               Viradouro
# 640        0   15.123104    Vista Alegre do Alto
# 641        0    3.396479          Vitória Brasil
# 642        0   10.398229              Votorantim
# 643        0    7.233832             Votuporanga
# 644        0    3.660493                Zacarias
#
# [645 rows x 3 columns]
# Iteration of Number:  6
# Variable excluded in this iteration: {'feature': 'private_inv', 'p-value': 0.091851832194846592}
# I-Distance rank:
#      Cluster  I-Distance                    city
# 0          0    3.378890              Adamantina
# 1          0    2.783089                  Adolfo
# 2          0    2.760523                   Aguaí
# 3          0    2.593397          Águas da Prata
# 4          0    3.098946        Águas de Lindóia
# 5          0    1.852727  Águas de Santa Bárbara
# 6          0    5.142657      Águas de São Pedro
# 7          0    8.296152                  Agudos
# 8          0    0.882173                Alambari
# 9          0    1.882651       Alfredo Marcondes
# 10         0    2.934439                  Altair
# 11         0    2.196695             Altinópolis
# 12         0    1.404890             Alto Alegre
# 13         0   52.560349                Alumínio
# 14         0    1.298940        Álvares Florence
# 15         0    2.360734         Álvares Machado
# 16         0    0.381523      Álvaro de Carvalho
# 17         0    2.085454             Alvinlândia
# 18         0   17.774734               Americana
# 19         0    5.348386     Américo Brasiliense
# 20         0    1.530359       Américo de Campos
# 21         0    6.997246                  Amparo
# 22         0    2.412159               Analândia
# 23         0    5.004059               Andradina
# 24         0    2.074976                Angatuba
# 25         0    3.006902                 Anhembi
# 26         0    1.667357                 Anhumas
# 27         0    3.361114               Aparecida
# 28         0    1.308143       Aparecida d'Oeste
# 29         0    1.739496                   Apiaí
# ..       ...         ...                     ...
# 615        0    3.099009                Tremembé
# 616        0    1.980412         Três Fronteiras
# 617        0    1.070352                  Tuiuti
# 618        0    3.535925                    Tupã
# 619        0    1.191009           Tupi Paulista
# 620        0    1.516702                 Turiúba
# 621        0    0.934997               Turmalina
# 622        0    8.149212                 Ubarana
# 623        0    3.067231                 Ubatuba
# 624        0    0.619749               Ubirajara
# 625        0    3.833588                   Uchoa
# 626        0    1.542329          União Paulista
# 627        0    1.732493                  Urânia
# 628        0    1.853868                     Uru
# 629        0    2.078025                  Urupês
# 630        0    2.549716         Valentim Gentil
# 631        0   14.090264                Valinhos
# 632        0    6.657252              Valparaíso
# 633        0    0.216594                  Vargem
# 634        0    2.832971    Vargem Grande do Sul
# 635        0    9.198171  Vargem Grande Paulista
# 636        0   15.443734         Várzea Paulista
# 637        0    1.738494               Vera Cruz
# 638        0   30.161082                 Vinhedo
# 639        0    2.386001               Viradouro
# 640        0   11.785706    Vista Alegre do Alto
# 641        0    1.993155          Vitória Brasil
# 642        0    7.320236              Votorantim
# 643        0    4.476984             Votuporanga
# 644        0    2.573962                Zacarias
#
# [645 rows x 3 columns]
# Iteration of Number:  7
# Variable excluded in this iteration: {'feature': 'urbing', 'p-value': 0.10763222822410638}
# I-Distance rank:
#      Cluster  I-Distance                    city
# 0          0    3.381772              Adamantina
# 1          0    2.784285                  Adolfo
# 2          0    2.762508                   Aguaí
# 3          0    2.595211          Águas da Prata
# 4          0    3.102472        Águas de Lindóia
# 5          0    1.853445  Águas de Santa Bárbara
# 6          0    5.147547      Águas de São Pedro
# 7          0    8.298872                  Agudos
# 8          0    0.883089                Alambari
# 9          0    1.884172       Alfredo Marcondes
# 10         0    2.935367                  Altair
# 11         0    2.198509             Altinópolis
# 12         0    1.406023             Alto Alegre
# 13         0   52.621951                Alumínio
# 14         0    1.299403        Álvares Florence
# 15         0    2.362668         Álvares Machado
# 16         0    0.381768      Álvaro de Carvalho
# 17         0    2.087392             Alvinlândia
# 18         0   14.535485               Americana
# 19         0    5.351816     Américo Brasiliense
# 20         0    1.531821       Américo de Campos
# 21         0    6.999554                  Amparo
# 22         0    2.413227               Analândia
# 23         0    5.007130               Andradina
# 24         0    2.075610                Angatuba
# 25         0    3.007379                 Anhembi
# 26         0    1.668710                 Anhumas
# 27         0    3.349952               Aparecida
# 28         0    1.309522       Aparecida d'Oeste
# 29         0    1.740442                   Apiaí
# ..       ...         ...                     ...
# 615        0    3.101248                Tremembé
# 616        0    1.981880         Três Fronteiras
# 617        0    1.070202                  Tuiuti
# 618        0    3.541709                    Tupã
# 619        0    1.192006           Tupi Paulista
# 620        0    1.517960                 Turiúba
# 621        0    0.935595               Turmalina
# 622        0    8.139457                 Ubarana
# 623        0    3.071419                 Ubatuba
# 624        0    0.620405               Ubirajara
# 625        0    3.835636                   Uchoa
# 626        0    1.543258          União Paulista
# 627        0    1.733962                  Urânia
# 628        0    1.854500                     Uru
# 629        0    2.079975                  Urupês
# 630        0    2.551868         Valentim Gentil
# 631        0   14.049568                Valinhos
# 632        0    6.659234              Valparaíso
# 633        0    0.216610                  Vargem
# 634        0    2.835712    Vargem Grande do Sul
# 635        0    9.209976  Vargem Grande Paulista
# 636        0   15.527562         Várzea Paulista
# 637        0    1.740205               Vera Cruz
# 638        0   30.100553                 Vinhedo
# 639        0    2.388736               Viradouro
# 640        0   11.786491    Vista Alegre do Alto
# 641        0    1.994509          Vitória Brasil
# 642        0    7.327091              Votorantim
# 643        0    4.143896             Votuporanga
# 644        0    2.574992                Zacarias
#
# [645 rows x 3 columns]
# Iterations needed:  7

# %%
distancec.sort_values('I-Distance', ascending=False)
# Out:
#      Cluster   I-Distance                     city
# 564        1  5420.100823                São Paulo
# 568        3   253.370130            São Sebastião
# 559        4   150.584562      São José dos Campos
# 234        0   142.742285            Ilha Comprida
# 546        4   120.551111    São Bernardo do Campo
# 153        0   114.357130                  Diadema
# 544        4   112.603475                   Santos
# 310        0   112.293461                 Louveira
# 590        0   104.851029          Taboão da Serra
# 64         2   102.321066                  Barueri
# 389        0   100.644117                   Osasco
# 547        0    91.586236       São Caetano do Sul
# 214        2    87.955723                Guarulhos
# 107        2    85.668883                 Campinas
# 120        0    78.343459              Carapicuíba
# 412        2    58.143407                 Paulínia
# 13         0    43.994971                 Alumínio
# 295        2    41.225816                  Jundiaí
# 583        2    40.666734                 Sorocaba
# 332        0    39.531636                     Mauá
# 536        2    36.173007              Santo André
# 282        0    35.980659               Jaguariúna
# 435        2    34.704392               Piracicaba
# 102        0    33.638510                  Cajamar
# 150        0    32.175117                  Cubatão
# 285        0    30.865753                  Jandira
# 219        0    28.588303              Hortolândia
# 446        0    28.108262                      Poá
# 606        2    26.810150                  Taubaté
# 194        0    26.311014           Gavião Peixoto
# ..       ...          ...                      ...
# 579        0     0.067592              Sete Barras
# 45         0     0.066880                  Aspásia
# 541        0     0.065759  Santo Antônio do Pinhal
# 164        0     0.062690                 Eldorado
# 273        0     0.060931                    Itobi
# 573        0     0.058822                 Sarutaiá
# 97         0     0.057360                  Caconde
# 329        0     0.055157              Marinópolis
# 60         0     0.051959          Barra do Chapéu
# 624        0     0.051210                Ubirajara
# 507        0     0.047334                Salmourão
# 141        0     0.045457           Coronel Macedo
# 272        0     0.039716                 Itirapuã
# 416        0     0.038255               Pedra Bela
# 238        0     0.037507                  Indiana
# 599        0     0.034734                 Taquaral
# 216        0     0.034345               Guzolândia
# 151        0     0.034056                    Cunha
# 263        0     0.033671               Itaporanga
# 556        0     0.033009     São José do Barreiro
# 245        0     0.027927                 Iporanga
# 40         0     0.022373                   Areias
# 542        0     0.020819           Santo Expedito
# 497        0     0.018268                 Riversul
# 299        0     0.018120                 Lagoinha
# 481        0     0.010638                  Ribeira
# 581        0     0.009802                Silveiras
# 459        0     0.007003                 Pracinha
# 293        0     0.005865           Júlio Mesquita
# 261        0     0.000000      Itapirapuã Paulista
#
# [645 rows x 3 columns]

# %%
rankc.sort_values('r', ascending=False)
# Out:
#          feature        p-value         r
# 5       violence   0.000000e+00  0.990580
# 12          jobs   0.000000e+00  0.989353
# 9   services_add   0.000000e+00  0.985795
# 7      value_add   0.000000e+00  0.982313
# 15     urban_pop   0.000000e+00  0.978691
# 14    population   0.000000e+00  0.978607
# 11    hosp_rooms   0.000000e+00  0.976214
# 17   fundamental   0.000000e+00  0.972127
# 2        pub_inv   0.000000e+00  0.951517
# 10    eletricity  8.198462e-314  0.944806
# 8   industry_add  4.002641e-288  0.933264
# 16     rural_pop  4.962174e-113  0.740399
# 4         import   1.767463e-86  0.673588
# 3         export   3.427779e-85  0.669827
# 6    density_pop   8.103492e-13  0.276907
# 13  jobs_revenue   3.553167e-05  0.162043
# 0        cluster   9.974276e-05  0.152614
# 1        gdp_per   1.193716e-02  0.098937

# %% [markdown]
# <h5>Looking for visual correlations for public investment and I-Distance  index

# %%
data_set = data_values[['city', 'pub_inv', 'gdp_per']] #getting public investment  and gdp per capita
scatter2 = distancec
scatterf2 = pd.merge(scatter2, data_set, on='city') # creating the dataset with the parameters for the scatter plot


sns.lmplot('pub_inv', 'I-Distance', scatterf2, hue='Cluster' , fit_reg=False)

# %% [markdown]
# There is no relationship when looking city by city

# %% [markdown]
# <h5>Trying separating with the clusters

# %%
x = scatterf2.groupby('Cluster', as_index=False).sum()

sns.lmplot('pub_inv', 'I-Distance', x , hue='Cluster', fit_reg=False, size=6, scatter_kws={"s": 150})

# %% [markdown]
# Here we can see that there is a clear positive correlation between the I-Distance index and the public investment value, when looking to the <b> sum </b> of the values considering the cluster. <br> <br>
#
# But we should try to use the median, because the cluster 0 has the big part of the cities, and this concetration could affect the picture.

# %%
y = scatterf2.groupby('Cluster', as_index=False).mean()

sns.lmplot('pub_inv', 'I-Distance', y , hue='Cluster', fit_reg=False, size=6, scatter_kws={"s": 150})

# %% [markdown]
# Here we could se some interesting relationship between cluster that evidenciates that influence of public investment within this group of cities
