# %% [markdown]
# # Final Code

# %% [markdown]
# <div class="alert alert-success">
# All of the concepts on choosing the subsets and data particularities in this code is concluded from the 'EDA - analysing Nans' notebook, which is also included in this repository. <br> <br>
#
# </div>

# %% [markdown]
# # Dataset tuning

# %% [markdown]
# All of this steps below are based on the EDA notebook also present in this repository.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Math, Latex
from scipy import stats, linalg
% matplotlib inline


df = pd.read_csv('SPcities2.csv', decimal=',', encoding='Iso-8859-1', sep=';')

## Seting the data as seeing in the EDA notebook ( also in this repository)
df = df[df.year > 2001]
df = df[df.year < 2016]

data = df[df.year == 2013] # like we saw in the EDA on missing values, 2013 should be the best year for our analysis
                           # this was the case because, for this method, we need the year with more information, 
                            # in this case 2013

# cleaning the all null features

data_clean = data
data_clean = data_clean.drop('HDI', 1)
data_clean = data_clean.drop('educ_superior', 1)
data_clean = data_clean.drop('tax_revenue', 1)

# %% [markdown]
# ------------------------------------------------ END OF DATASET TUNING ----------------------------------------------

# %% [markdown]
# The I-Distance method:

# %% [markdown]
# <img src='idistance.png'> </img>

# %% [markdown]
# <img src='disceffect.png'> </img>

# %% [markdown]
# "where di(r, s) is the distance between the values of variable Xi for er and es e.g. the discriminate effect" and <br> <br>
#
# "σi the standard deviation of Xi, and rji.12 … j − 1 is a partial coefficient of the correlation between Xi and Xj, (j < i)"

# %% [markdown]
# # Creating the tools to use the method

# %%
# this idea for partial correlation was obtained from : https://gist.github.com/fabianp/9396204419c7b638d38f

## Partial Correlation Matrix for the rij variable in the formula

from scipy import stats, linalg

def partial_corr(C):
    """
    Returns the sample linear partial correlation coefficients between pairs of variables in C, controlling 
    for the remaining variables in C.
    Parameters
    ----------
    C : array-like, shape (n, p)
        Array with the different variables. Each column of C is taken as a variable
    Returns
    -------
    P : array-like, shape (p, p)
        P[i, j] contains the partial correlation of C[:, i] and C[:, j] controlling
        for the remaining variables in C.
    """
    
    C = np.asarray(C)
    p = C.shape[1]
    P_corr = np.zeros((p, p), dtype=np.float)
    for i in range(p):
        P_corr[i, i] = 1
        for j in range(i+1, p):
            idx = np.ones(p, dtype=np.bool)
            idx[i] = False
            idx[j] = False
            beta_i = linalg.lstsq(C[:, idx], C[:, j])[0]
            beta_j = linalg.lstsq(C[:, idx], C[:, i])[0]

            res_j = C[:, j] - C[:, idx].dot( beta_i)
            res_i = C[:, i] - C[:, idx].dot(beta_j)
            
            corr = stats.pearsonr(res_i, res_j)[0]
            P_corr[i, j] = corr
            P_corr[j, i] = corr

        
    return P_corr

# %%
# The reference hyperplane to calculate all the distances from.
# Here we are going to set the city with the smallest value for GDP per capita

data_clean.sort_values('gdp_per', ascending=True).head()
# Out:
#                       city  year  gdp_per  gdp_growth  private_inv  \
# 4450   Itapirapuã Paulista  2013  6956.90    0.098176          NaN
# 10196             Taquaral  2013  7307.11   -0.110965          NaN
# 8462              Riversul  2013  7386.98    0.132233          NaN
# 7816              Pracinha  2013  7650.01    0.210545          NaN
# 285     Álvaro de Carvalho  2013  7653.97   -0.031318          NaN
#
#           pub_inv  export  import  violence  primary_enrolls     ...       \
# 4450    917044.27     NaN     NaN        12           102.25     ...
# 10196    91200.00     NaN     NaN         9            89.24     ...
# 8462          NaN     NaN     NaN        72            94.24     ...
# 7816          NaN     NaN     NaN         7            99.51     ...
# 285    1162680.60     NaN     NaN        29           100.62     ...
#
#        hosp_rooms  hosp_rooms_per   jobs  jobs_revenue  population  urban_pop  \
# 4450          NaN             NaN  521.0       1266.38        3954       1959
# 10196         NaN             NaN  500.0       1159.92        2729       2623
# 8462          NaN             NaN  533.0       1188.74        6003       4423
# 7816          NaN             NaN  264.0       1307.56        2864       1372
# 285           NaN             NaN  359.0       1443.34        4763       3081
#
#        rural_pop  olding  urbing  fundamental
# 4450      1995.0   42.32   49.54         64.0
# 10196      106.0   74.68   96.12         34.0
# 8462      1580.0   76.79   73.68         64.0
# 7816      1492.0   77.06   47.91         17.0
# 285       1682.0   60.52   64.69         55.0
#
# [5 rows x 26 columns]

# %% [markdown]
# Here, since the city of Itapirapua Paulista has the smallest value for the features of our most interest, it will be the hyperplane reference for our calculations.

# %%
data_values = data_clean.drop('year' ,1).fillna(0) # Base dataset for all calculations


reference = data_values.sort_values('gdp_per', ascending=True).iloc[0:1,:] # Base reference for all calculations

# %% [markdown]
# # Building the function to calculate the I-distance

# %% [markdown]
# Like the steps followed by <a href="http://www.sciencedirect.com/science/article/pii/S0264999314000558">reference article </a> , we should : <br>
#
# <ol>
# <li>Calculate the value of the discriminate effect of the variable X1, the most significant variable, that which provides the largest amount of information on the phenomena that is to be ranked; </li>
# <li> Add the value of the discriminate effect of X2 which is not covered by X1;</li>
# <li> Add the value of the discriminate effect of X3 which is not covered by X1 and X2;</li>
# <li> Repeat the procedure for all variables;</li>
# <li> Calculte the correlation coefficient of each indicator with the I-distance;</li>
# <li> Exclude the smallest non significant coefficient;</li>
# <li> Repeat (6) until only significant features remain.</li>

# %%
## Creating a function to the calculation to operate 1-4 above: 

def I_distance(data_values, reference):
    
    #getting the correlation matrix done
    data_corr = data_values.drop('city' ,1).fillna(0)
    col_labels = list(data_corr.columns)
    corre = pd.DataFrame(partial_corr(data_corr), columns=col_labels)
                         
    #starting the I-Distance calculation                     
    ncolums = data_corr.shape[1]
    nrows = data_corr.shape[0]
    somatory = []
    i2_index = {'city': [], 'I-Distance': []}
    for r in range(0,nrows):
        somatory = []    
        for i in range(0,ncolums):
            prod = 1
            summ_1 = 0
            summ_1 = ((data_corr.iloc[r,i] - reference.iloc[0,i+1])**2)/np.var(data_corr.iloc[:,i]) #distance squared divided by variance
            for k in range(i+1):
                if corre.iloc[i,k] == 1:
                    prod *= 1
                else:
                    prod *= (1-(corre.iloc[i,k])**2)
            somatory.append(summ_1*prod)
        i2_index['city'].append(data_values.iloc[r,0])
        i2_index['I-Distance'].append(np.cumsum(somatory)[-1])
    

## 5 - 6 selecting sigficant features

# calculating the rank of features and p-values

    distance = pd.DataFrame(i2_index)

    data = data_values.iloc[:,1:]
    feature_rank = {'feature': [], 'r': [], 'p-value': []}

    # creating the rank with correlation, p-values and name of features
    for col, values in data.iteritems():
        feature_rank['feature'].append(col)
        feature_rank['r'].append(stats.pearsonr(values, distance['I-Distance'])[0])
        feature_rank['p-value'].append(stats.pearsonr(values, distance['I-Distance'])[1])
    

    # manipulating the rank to select smallest correlation value with no significant p-value valor (>0.01)
    rank = pd.DataFrame(feature_rank)
    lenght_rank = len(list(rank.columns))
  
    excluded = {'feature' : "" , 'p-value' : 0 }
    for x in range(lenght_rank):
        excluded = {'feature' : "" , 'p-value' : 0 }
        chk = 0
        if rank.sort_values('r').iloc[x,1] >= 0.05 and x <= lenght_rank:  # check if the smallest r value is significant
            excluded['feature'] = rank.sort_values('r').iloc[x,0]
            excluded['p-value'] = rank.sort_values('r').iloc[x,1]
            chk = 1
            break
        elif rank.sort_values('r').iloc[x,1] <= 0.05 and x == lenght_rank:
            chk = 0
            break
        else:
            chk = 0
            continue

    if chk == 1: # returning new data frame if there is some variable to exclude, otherwise is done
        n_values = data_values.drop(excluded['feature'], 1)
        n_ref = reference.drop(excluded['feature'], 1)
        return 'loop',distance,  n_values, n_ref, excluded
    else:
        return 'done', distance, rank, 'ref', excluded # if no features to drop, return distance and rank

# %%
# 7 - Iterating for the final model until we gett only significant features:

def Final_distance(data_values, reference):
    check, distance, rank, ref, excluded = I_distance(data_values, reference)
    
    cont=1
    while True:
        if check == 'loop':
            print("Iteration of Number: ", cont)
            print("Variable excluded in this iteration:", excluded )
            print("I-Distance rank:")
            print(distance)
            check, distance, rank, ref, excluded = I_distance(rank, ref)
            cont += 1
            continue
        else:
            print("Iterations needed: ", cont-1)
            break
    return check, distance, rank

# %%
check1, distance1, rank1 = Final_distance(data_values, reference)
# Out:
# Iteration of Number:  1
# Variable excluded in this iteration: {'feature': 'olding', 'p-value': 0.62152333001401172}
# I-Distance rank:
#      I-Distance                    city
# 0     19.574375              Adamantina
# 1     12.623635                  Adolfo
# 2      7.619452                   Aguaí
# 3     14.912675          Águas da Prata
# 4     10.553639        Águas de Lindóia
# 5      4.973449  Águas de Santa Bárbara
# 6    175.278901      Águas de São Pedro
# 7     14.560906                  Agudos
# 8      2.860073                Alambari
# 9     13.647056       Alfredo Marcondes
# 10     7.707353                  Altair
# 11     9.946214             Altinópolis
# 12    16.617030             Alto Alegre
# 13    55.358300                Alumínio
# 14    20.329446        Álvares Florence
# 15     6.563823         Álvares Machado
# 16     1.786611      Álvaro de Carvalho
# 17     5.934405             Alvinlândia
# 18    24.343443               Americana
# 19    12.963261     Américo Brasiliense
# 20     8.488222       Américo de Campos
# 21    17.353354                  Amparo
# 22     5.603509               Analândia
# 23    14.095144               Andradina
# 24     6.805986                Angatuba
# 25     4.664807                 Anhembi
# 26     7.810902                 Anhumas
# 27     9.137248               Aparecida
# 28    15.335710       Aparecida d'Oeste
# 29    15.155430                   Apiaí
# ..          ...                     ...
# 615    7.572549                Tremembé
# 616   11.985928         Três Fronteiras
# 617    6.288230                  Tuiuti
# 618   31.352973                    Tupã
# 619   16.739678           Tupi Paulista
# 620   14.743482                 Turiúba
# 621   20.412176               Turmalina
# 622   12.547339                 Ubarana
# 623    7.724365                 Ubatuba
# 624    3.258099               Ubirajara
# 625   11.290331                   Uchoa
# 626    4.647153          União Paulista
# 627   14.196895                  Urânia
# 628   12.986362                     Uru
# 629   11.955711                  Urupês
# 630    6.484321         Valentim Gentil
# 631   21.712239                Valinhos
# 632   15.234602              Valparaíso
# 633    2.670726                  Vargem
# 634    8.557061    Vargem Grande do Sul
# 635   13.193756  Vargem Grande Paulista
# 636   23.867952         Várzea Paulista
# 637    9.494356               Vera Cruz
# 638   36.151840                 Vinhedo
# 639    7.756703               Viradouro
# 640   16.947887    Vista Alegre do Alto
# 641    7.139492          Vitória Brasil
# 642   12.010807              Votorantim
# 643   12.373834             Votuporanga
# 644    7.056343                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  2
# Variable excluded in this iteration: {'feature': 'agriculture_add', 'p-value': 0.98214452581462652}
# I-Distance rank:
#      I-Distance                    city
# 0     12.565135              Adamantina
# 1      8.237832                  Adolfo
# 2      6.473223                   Aguaí
# 3      7.944431          Águas da Prata
# 4      7.474909        Águas de Lindóia
# 5      3.257135  Águas de Santa Bárbara
# 6    153.321597      Águas de São Pedro
# 7     13.165581                  Agudos
# 8      2.302434                Alambari
# 9      4.100359       Alfredo Marcondes
# 10     7.019580                  Altair
# 11     7.216637             Altinópolis
# 12     7.175273             Alto Alegre
# 13    54.324494                Alumínio
# 14     3.925371        Álvares Florence
# 15     4.559774         Álvares Machado
# 16     1.285320      Álvaro de Carvalho
# 17     4.694774             Alvinlândia
# 18    21.467634               Americana
# 19    11.653476     Américo Brasiliense
# 20     3.085680       Américo de Campos
# 21    14.479077                  Amparo
# 22     4.157325               Analândia
# 23    10.494061               Andradina
# 24     6.175475                Angatuba
# 25     4.099479                 Anhembi
# 26     6.085563                 Anhumas
# 27     7.217824               Aparecida
# 28     7.150848       Aparecida d'Oeste
# 29    14.673726                   Apiaí
# ..          ...                     ...
# 615    6.457107                Tremembé
# 616    4.936881         Três Fronteiras
# 617    1.764630                  Tuiuti
# 618   25.429166                    Tupã
# 619    3.872468           Tupi Paulista
# 620    3.188496                 Turiúba
# 621    2.075862               Turmalina
# 622   11.621415                 Ubarana
# 623    6.552524                 Ubatuba
# 624    2.022607               Ubirajara
# 625    6.363561                   Uchoa
# 626    3.269775          União Paulista
# 627    8.136005                  Urânia
# 628    8.359820                     Uru
# 629    5.834769                  Urupês
# 630    4.685406         Valentim Gentil
# 631   19.373022                Valinhos
# 632   13.776485              Valparaíso
# 633    0.897489                  Vargem
# 634    6.841239    Vargem Grande do Sul
# 635   11.867828  Vargem Grande Paulista
# 636   22.436770         Várzea Paulista
# 637    6.181559               Vera Cruz
# 638   34.311626                 Vinhedo
# 639    5.848384               Viradouro
# 640   15.470301    Vista Alegre do Alto
# 641    3.371135          Vitória Brasil
# 642   10.819934              Votorantim
# 643    8.126330             Votuporanga
# 644    4.067361                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  3
# Variable excluded in this iteration: {'feature': 'gdp_growth', 'p-value': 0.75378316318785343}
# I-Distance rank:
#      I-Distance                    city
# 0     12.115960              Adamantina
# 1      8.042414                  Adolfo
# 2      5.056758                   Aguaí
# 3      7.970469          Águas da Prata
# 4      7.530465        Águas de Lindóia
# 5      3.121306  Águas de Santa Bárbara
# 6    153.385922      Águas de São Pedro
# 7     11.496496                  Agudos
# 8      2.146873                Alambari
# 9      4.127744       Alfredo Marcondes
# 10     6.104993                  Altair
# 11     4.710981             Altinópolis
# 12     7.030864             Alto Alegre
# 13    54.204979                Alumínio
# 14     3.683619        Álvares Florence
# 15     4.430957         Álvares Machado
# 16     1.286850      Álvaro de Carvalho
# 17     4.724730             Alvinlândia
# 18    21.516335               Americana
# 19    11.599996     Américo Brasiliense
# 20     3.041638       Américo de Campos
# 21    10.372747                  Amparo
# 22     4.092833               Analândia
# 23     7.878665               Andradina
# 24     3.677725                Angatuba
# 25     3.797024                 Anhembi
# 26     5.817042                 Anhumas
# 27     7.273129               Aparecida
# 28     7.178189       Aparecida d'Oeste
# 29     5.120838                   Apiaí
# ..          ...                     ...
# 615    6.492500                Tremembé
# 616    4.911640         Três Fronteiras
# 617    1.509872                  Tuiuti
# 618   22.872681                    Tupã
# 619    3.544113           Tupi Paulista
# 620    3.200305                 Turiúba
# 621    2.072378               Turmalina
# 622   11.407513                 Ubarana
# 623    6.564373                 Ubatuba
# 624    2.032332               Ubirajara
# 625    6.009438                   Uchoa
# 626    3.225777          União Paulista
# 627    7.625911                  Urânia
# 628    8.397352                     Uru
# 629    4.814990                  Urupês
# 630    4.658696         Valentim Gentil
# 631   19.139425                Valinhos
# 632   10.441102              Valparaíso
# 633    0.891691                  Vargem
# 634    6.320430    Vargem Grande do Sul
# 635   11.795515  Vargem Grande Paulista
# 636   22.504668         Várzea Paulista
# 637    6.202632               Vera Cruz
# 638   34.293691                 Vinhedo
# 639    5.693407               Viradouro
# 640   15.366013    Vista Alegre do Alto
# 641    3.397748          Vitória Brasil
# 642   10.853895              Votorantim
# 643    8.018165             Votuporanga
# 644    3.869522                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  4
# Variable excluded in this iteration: {'feature': 'hosp_rooms_per', 'p-value': 0.37582986912677707}
# I-Distance rank:
#      I-Distance                    city
# 0     12.074408              Adamantina
# 1      4.983056                  Adolfo
# 2      4.855316                   Aguaí
# 3      7.984253          Águas da Prata
# 4      6.493129        Águas de Lindóia
# 5      2.764992  Águas de Santa Bárbara
# 6    155.455462      Águas de São Pedro
# 7     10.964515                  Agudos
# 8      1.969329                Alambari
# 9      3.406097       Alfredo Marcondes
# 10     6.010449                  Altair
# 11     4.293898             Altinópolis
# 12     5.720671             Alto Alegre
# 13    53.406963                Alumínio
# 14     1.780894        Álvares Florence
# 15     4.300596         Álvares Machado
# 16     0.654141      Álvaro de Carvalho
# 17     4.639451             Alvinlândia
# 18    21.395524               Americana
# 19    11.105158     Américo Brasiliense
# 20     3.003254       Américo de Campos
# 21    10.358998                  Amparo
# 22     4.057398               Analândia
# 23     7.826774               Andradina
# 24     3.645955                Angatuba
# 25     3.646621                 Anhembi
# 26     3.946382                 Anhumas
# 27     7.146007               Aparecida
# 28     7.092592       Aparecida d'Oeste
# 29     2.952057                   Apiaí
# ..          ...                     ...
# 615    6.378912                Tremembé
# 616    4.341462         Três Fronteiras
# 617    1.494770                  Tuiuti
# 618   22.856244                    Tupã
# 619    3.478590           Tupi Paulista
# 620    2.824821                 Turiúba
# 621    1.833297               Turmalina
# 622   10.937159                 Ubarana
# 623    5.932251                 Ubatuba
# 624    1.858186               Ubirajara
# 625    5.893334                   Uchoa
# 626    3.185582          União Paulista
# 627    7.650905                  Urânia
# 628    8.394868                     Uru
# 629    4.562016                  Urupês
# 630    4.576849         Valentim Gentil
# 631   19.178361                Valinhos
# 632   10.272428              Valparaíso
# 633    0.323254                  Vargem
# 634    6.109250    Vargem Grande do Sul
# 635   11.752717  Vargem Grande Paulista
# 636   22.591595         Várzea Paulista
# 637    6.010498               Vera Cruz
# 638   34.123638                 Vinhedo
# 639    5.619110               Viradouro
# 640   15.200454    Vista Alegre do Alto
# 641    3.337205          Vitória Brasil
# 642   10.458604              Votorantim
# 643    7.813758             Votuporanga
# 644    3.614522                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  5
# Variable excluded in this iteration: {'feature': 'primary_enrolls', 'p-value': 0.20131162083727402}
# I-Distance rank:
#      I-Distance                    city
# 0      5.797765              Adamantina
# 1      5.065967                  Adolfo
# 2      4.937450                   Aguaí
# 3      8.065789          Águas da Prata
# 4      6.096651        Águas de Lindóia
# 5      2.798153  Águas de Santa Bárbara
# 6    155.508127      Águas de São Pedro
# 7     10.753398                  Agudos
# 8      2.007895                Alambari
# 9      3.471201       Alfredo Marcondes
# 10     6.055808                  Altair
# 11     4.011196             Altinópolis
# 12     3.136352             Alto Alegre
# 13    53.386888                Alumínio
# 14     1.800728        Álvares Florence
# 15     4.316100         Álvares Machado
# 16     0.664901      Álvaro de Carvalho
# 17     4.722496             Alvinlândia
# 18    20.621770               Americana
# 19     8.345475     Américo Brasiliense
# 20     3.065581       Américo de Campos
# 21     7.951003                  Amparo
# 22     4.104494               Analândia
# 23     7.385984               Andradina
# 24     3.109510                Angatuba
# 25     3.674090                 Anhembi
# 26     4.004755                 Anhumas
# 27     6.746526               Aparecida
# 28     2.835838       Aparecida d'Oeste
# 29     2.603190                   Apiaí
# ..          ...                     ...
# 615    6.415927                Tremembé
# 616    4.405875         Três Fronteiras
# 617    1.491593                  Tuiuti
# 618    6.064344                    Tupã
# 619    2.533077           Tupi Paulista
# 620    2.878626                 Turiúba
# 621    1.859344               Turmalina
# 622   11.019952                 Ubarana
# 623    5.967525                 Ubatuba
# 624    1.886336               Ubirajara
# 625    5.983672                   Uchoa
# 626    3.225402          União Paulista
# 627    6.921790                  Urânia
# 628    8.477158                     Uru
# 629    4.011759                  Urupês
# 630    4.665821         Valentim Gentil
# 631   19.046796                Valinhos
# 632    9.848543              Valparaíso
# 633    0.323617                  Vargem
# 634    5.874743    Vargem Grande do Sul
# 635   11.857846  Vargem Grande Paulista
# 636   22.677522         Várzea Paulista
# 637    6.084709               Vera Cruz
# 638   34.029307                 Vinhedo
# 639    5.060882               Viradouro
# 640   15.123104    Vista Alegre do Alto
# 641    3.396479          Vitória Brasil
# 642   10.398229              Votorantim
# 643    7.233832             Votuporanga
# 644    3.660493                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  6
# Variable excluded in this iteration: {'feature': 'private_inv', 'p-value': 0.091851832194846592}
# I-Distance rank:
#      I-Distance                    city
# 0      3.378890              Adamantina
# 1      2.783089                  Adolfo
# 2      2.760523                   Aguaí
# 3      2.593397          Águas da Prata
# 4      3.098946        Águas de Lindóia
# 5      1.852727  Águas de Santa Bárbara
# 6      5.142657      Águas de São Pedro
# 7      8.296152                  Agudos
# 8      0.882173                Alambari
# 9      1.882651       Alfredo Marcondes
# 10     2.934439                  Altair
# 11     2.196695             Altinópolis
# 12     1.404890             Alto Alegre
# 13    52.560349                Alumínio
# 14     1.298940        Álvares Florence
# 15     2.360734         Álvares Machado
# 16     0.381523      Álvaro de Carvalho
# 17     2.085454             Alvinlândia
# 18    17.774734               Americana
# 19     5.348386     Américo Brasiliense
# 20     1.530359       Américo de Campos
# 21     6.997246                  Amparo
# 22     2.412159               Analândia
# 23     5.004059               Andradina
# 24     2.074976                Angatuba
# 25     3.006902                 Anhembi
# 26     1.667357                 Anhumas
# 27     3.361114               Aparecida
# 28     1.308143       Aparecida d'Oeste
# 29     1.739496                   Apiaí
# ..          ...                     ...
# 615    3.099009                Tremembé
# 616    1.980412         Três Fronteiras
# 617    1.070352                  Tuiuti
# 618    3.535925                    Tupã
# 619    1.191009           Tupi Paulista
# 620    1.516702                 Turiúba
# 621    0.934997               Turmalina
# 622    8.149212                 Ubarana
# 623    3.067231                 Ubatuba
# 624    0.619749               Ubirajara
# 625    3.833588                   Uchoa
# 626    1.542329          União Paulista
# 627    1.732493                  Urânia
# 628    1.853868                     Uru
# 629    2.078025                  Urupês
# 630    2.549716         Valentim Gentil
# 631   14.090264                Valinhos
# 632    6.657252              Valparaíso
# 633    0.216594                  Vargem
# 634    2.832971    Vargem Grande do Sul
# 635    9.198171  Vargem Grande Paulista
# 636   15.443734         Várzea Paulista
# 637    1.738494               Vera Cruz
# 638   30.161082                 Vinhedo
# 639    2.386001               Viradouro
# 640   11.785706    Vista Alegre do Alto
# 641    1.993155          Vitória Brasil
# 642    7.320236              Votorantim
# 643    4.476984             Votuporanga
# 644    2.573962                Zacarias
#
# [645 rows x 2 columns]
# Iteration of Number:  7
# Variable excluded in this iteration: {'feature': 'urbing', 'p-value': 0.10763222822410638}
# I-Distance rank:
#      I-Distance                    city
# 0      3.381772              Adamantina
# 1      2.784285                  Adolfo
# 2      2.762508                   Aguaí
# 3      2.595211          Águas da Prata
# 4      3.102472        Águas de Lindóia
# 5      1.853445  Águas de Santa Bárbara
# 6      5.147547      Águas de São Pedro
# 7      8.298872                  Agudos
# 8      0.883089                Alambari
# 9      1.884172       Alfredo Marcondes
# 10     2.935367                  Altair
# 11     2.198509             Altinópolis
# 12     1.406023             Alto Alegre
# 13    52.621951                Alumínio
# 14     1.299403        Álvares Florence
# 15     2.362668         Álvares Machado
# 16     0.381768      Álvaro de Carvalho
# 17     2.087392             Alvinlândia
# 18    14.535485               Americana
# 19     5.351816     Américo Brasiliense
# 20     1.531821       Américo de Campos
# 21     6.999554                  Amparo
# 22     2.413227               Analândia
# 23     5.007130               Andradina
# 24     2.075610                Angatuba
# 25     3.007379                 Anhembi
# 26     1.668710                 Anhumas
# 27     3.349952               Aparecida
# 28     1.309522       Aparecida d'Oeste
# 29     1.740442                   Apiaí
# ..          ...                     ...
# 615    3.101248                Tremembé
# 616    1.981880         Três Fronteiras
# 617    1.070202                  Tuiuti
# 618    3.541709                    Tupã
# 619    1.192006           Tupi Paulista
# 620    1.517960                 Turiúba
# 621    0.935595               Turmalina
# 622    8.139457                 Ubarana
# 623    3.071419                 Ubatuba
# 624    0.620405               Ubirajara
# 625    3.835636                   Uchoa
# 626    1.543258          União Paulista
# 627    1.733962                  Urânia
# 628    1.854500                     Uru
# 629    2.079975                  Urupês
# 630    2.551868         Valentim Gentil
# 631   14.049568                Valinhos
# 632    6.659234              Valparaíso
# 633    0.216610                  Vargem
# 634    2.835712    Vargem Grande do Sul
# 635    9.209976  Vargem Grande Paulista
# 636   15.527562         Várzea Paulista
# 637    1.740205               Vera Cruz
# 638   30.100553                 Vinhedo
# 639    2.388736               Viradouro
# 640   11.786491    Vista Alegre do Alto
# 641    1.994509          Vitória Brasil
# 642    7.327091              Votorantim
# 643    4.143896             Votuporanga
# 644    2.574992                Zacarias
#
# [645 rows x 2 columns]
# Iterations needed:  8

# %% [markdown]
# As we can see, of the features of our interest, public investment seems to be a important one, once it 'survived'and has as relevant participation on the index calculation. Otherwise, private investment seems to be irrelevant for economic growth in this particular case. <br><br>
#
# Now, let's make some separate experiments and, using the same year of 2013, try to isolate our 2 variables of interest, public and private investment, and see how they perform without each others presence only in the city where they have not null entries. <b>This seeks to answer wheter, in the cities where they are important, what are their relevance in the I-Distance model.

# %% [markdown]
# <h4>Public Investment: </h4>

# %%
# let's prepare our dataset 

public = data_clean[data_clean.pub_inv.notnull()].drop(['year', 'private_inv'], 1).fillna(0) #this will be our dataset for this part

public.head(5)

# %%
# Let`s get our reference, being the minimum value for GDP per capita, as we did above

pub_ref = public.sort_values('gdp_per', ascending=True).iloc[0:1,:]
pub_ref # it will be the same city, but we now have our reference

# %%
checkpub1, distancepub1, rankpub1 = Final_distance(public, pub_ref)

# %%
rankpub1.sort_values('r', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-5e39cf168d83> in <module>()
# ----> 1 rankpub1.sort_values('r', ascending=False)
#
# NameError: name 'rankpub1' is not defined

# %% [markdown]
# It looks like the situation from our first run remains the same, so public investment is still relevant and in the same level, in the cities where it appears in the year of 2013. <br><br>
#
# Let's take a look on the private investment:

# %% [markdown]
# <b> Private Investment

# %%
# let's prepare our dataset 

private = data_clean[data_clean.private_inv.notnull()].drop(['year', 'pub_inv'], 1).fillna(0) #this will be our dataset for this part

private.head(5)

# %%
# Let`s get our reference, being the minimum value for GDP per capita, as we did above

priv_ref = private.sort_values('gdp_per', ascending=True).iloc[0:1,:]
priv_ref # this is a different city from the other 2 situations

# %%
checkpri1, distancepri1, rankpri1 = Final_distance(private, priv_ref)

# %%
rankpri1.sort_values('r', ascending=False)

# %% [markdown]
# <div class="alert alert-success">
# Here we could see that 2013 should be the better year to apply the method since we have the most of our main predictors. <br> <br>
#
# Another thing is that, beginning from 2010 and going to 2013, could be a good period if we choose to use the mean of more than 1 years to calcule the hyperplanes, since we have important data concetrated in this years.  <br>
# </div>
